# %% [markdown]
# # 📌 Penjelasan Naïve Bayes & Alasan Langkah-langkahnya
#
# ## 🧠 Apa itu Naïve Bayes?
# Naïve Bayes adalah algoritma klasifikasi berbasis **Teorema Bayes**, yang mengasumsikan bahwa setiap fitur dalam dataset **bersifat independen** satu sama lain. Meskipun asumsi ini jarang 100% benar di dunia nyata, Naïve Bayes tetap **sangat efektif** dalam banyak kasus seperti **klasifikasi teks, deteksi spam, dan analisis sentimen**.
#
# ## 🔥 Mengapa Naïve Bayes Penting?
#
# Naïve Bayes memiliki beberapa **keunggulan utama**, di antaranya:
#
# 1️⃣ **Cepat dan Efisien** 🚀
#    - Naïve Bayes sangat cepat dalam melakukan training, bahkan pada dataset besar.
#    - Algoritma ini memiliki **kompleksitas rendah**, biasanya hanya **O(n)** di mana \( n \) adalah jumlah data.
#
# 2️⃣ **Bekerja dengan Data Kecil** 🔍
#    - Dibandingkan dengan algoritma lain seperti Neural Networks atau SVM, Naïve Bayes dapat bekerja dengan baik meskipun data latihnya **terbatas**.
#
# 3️⃣ **Performa Baik dalam Klasifikasi Teks & NLP** 📝
#    - Digunakan luas dalam **deteksi spam, analisis sentimen, dan rekomendasi produk** karena kemampuannya mengelola data kategorikal dan teks.
#
# 4️⃣ **Tidak Mudah Overfitting** 🛡
#    - Karena algoritma ini hanya bergantung pada probabilitas sederhana, Naïve Bayes lebih **stabil terhadap overfitting**, terutama dibandingkan dengan model kompleks lainnya.
#
# 5️⃣ **Dapat Menangani Banyak Fitur** 🏗
#    - Meskipun fitur dalam dataset dianggap independen (asumsi naive), algoritma tetap bisa bekerja **baik dalam praktik** meskipun fitur-fitur memiliki sedikit korelasi.
#
# ### 🔢 Rumus dasar **Teorema Bayes**:
#
# $$
# P(A|B) = \frac{P(B|A) \cdot P(A)}{P(B)}
# $$
#
# Di mana:
# - \( P(A|B) \) = Probabilitas kejadian **A terjadi** jika **B sudah terjadi**
# - \( P(B|A) \) = Probabilitas **B terjadi** jika **A terjadi**
# - \( P(A) \) = Probabilitas awal **A**
# - \( P(B) \) = Probabilitas awal **B**
#
#
#
# ---

# %% [markdown]
# ## 🔄 Langkah-langkah Ini Diperlukan
#
# ### 1️⃣ Mengambil Data dari MySQL & PostgreSQL
# - Data yang kita pakai kali ini berasal dari database MySQL dan PostgreSQL
# - Mengambil data dari kedua database ini memastikan kita memiliki dataset yang lengkap dan lebih representatif.

# %%
# !pip install pymysql
# !pip install psycopg2
# !pip install tabulate
# Out:
# Requirement already satisfied: pymysql in /usr/local/lib/python3.11/dist-packages (1.1.1)
# Requirement already satisfied: psycopg2 in /usr/local/lib/python3.11/dist-packages (2.9.10)
# Requirement already satisfied: tabulate in /usr/local/lib/python3.11/dist-packages (0.9.0)

# %%
import pymysql
import pandas as pd

# Koneksi ke MySQL
mysql_conn = pymysql.connect(
    host="mysql-34425cbd-irismysqlaldi.h.aivencloud.com",
    port=22476,
    user="avnadmin",
    password="AVNS_QsQ7Yf7zzcmrk83yFgg",
    db="irismysqlaldi",
    charset="utf8mb4",
    cursorclass=pymysql.cursors.DictCursor
)

# Ambil data dari MySQL
with mysql_conn.cursor() as mysql_cur:
    mysql_cur.execute("SELECT id, class, `petal length`, `petal width` FROM flowers")
    mysql_data = mysql_cur.fetchall()
mysql_df = pd.DataFrame(mysql_data)
print("Data dari MySQL:")
print(mysql_df.head())

mysql_conn.close()
# Out:
# Data dari MySQL:
#    id        class  petal length  petal width
# 0   1  Iris-setosa          86.4         70.0
# 1   2  Iris-setosa           1.4          0.2
# 2   3  Iris-setosa           1.3          0.2
# 3   4  Iris-setosa           1.5          0.2
# 4   5  Iris-setosa           1.4          0.2

# %%
import psycopg2
import pandas as pd

# Koneksi ke PostgreSQL
pg_conn = psycopg2.connect(
    "postgres://avnadmin:AVNS_0S2t3zth51a__4WQCdz@pg-2c20c354-pendataku.h.aivencloud.com:26053/defaultdb?sslmode=require"
)
pg_cur = pg_conn.cursor()

# Ambil data dari PostgreSQL
pg_cur.execute("SELECT id, class, sepal_length, sepal_width FROM flowers")
pg_data = pg_cur.fetchall()
pg_columns = [desc[0] for desc in pg_cur.description]
pg_df = pd.DataFrame(pg_data, columns=pg_columns)
print("Data dari PostgreSQL:")
print(pg_df.head())

pg_cur.close()
pg_conn.close()
# Out:
# Data dari PostgreSQL:
#    id        class  sepal_length  sepal_width
# 0   1  Iris-setosa          20.1         30.5
# 1   2  Iris-setosa           4.9          3.0
# 2   3  Iris-setosa           4.7          3.2
# 3   4  Iris-setosa           4.6          3.1
# 4   5  Iris-setosa           5.0          3.6

# %% [markdown]
# ### 2️⃣ Menggabungkan Data
# - Karena kita mengambil dari dua sumber berbeda, kita perlu **menggabungkannya** untuk membentuk dataset yang siap diproses.
# - Teknik yang digunakan**join berdasarkan ID**.
# berikut code untuk penggabungan data

# %%
# Join data berdasarkan 'id' dan 'class'
data_asli = pd.merge(mysql_df, pg_df, on=['id', 'class'], how='inner')

# Tentukan panjang maksimum tiap kolom agar tidak geser
col_widths = {
  "id": max(data_asli["id"].astype(str).apply(len).max(), 3),
  "class": max(data_asli["class"].astype(str).apply(len).max(), 6),
  "petal length": 13,
  "petal width": 12,
  "sepal_length": 13,
  "sepal_width": 12,
}

# Header tabel
header = f"| {'ID':<{col_widths['id']}} | {'Class':<{col_widths['class']}} | {'Petal Length':<{col_widths['petal length']}} | {'Petal Width':<{col_widths['petal width']}} | {'Sepal Length':<{col_widths['sepal_length']}} | {'Sepal Width':<{col_widths['sepal_width']}} |"
separator = "+" + "+".join(["-" * (col_widths[col] + 2) for col in col_widths]) + "+"

print(separator)
print(header)
print(separator)

# Isi tabel
for _, row in data_asli.iterrows():
  print(f"| {str(row['id']):<{col_widths['id']}} | {str(row['class']):<{col_widths['class']}} | {str(row['petal length']):<{col_widths['petal length']}} | {str(row['petal width']):<{col_widths['petal width']}} | {str(row['sepal_length']):<{col_widths['sepal_length']}} | {str(row['sepal_width']):<{col_widths['sepal_width']}} |")

print(separator)
# Out:
# +-----+-----------------+---------------+--------------+---------------+--------------+
# | ID  | Class           | Petal Length  | Petal Width  | Sepal Length  | Sepal Width  |
# +-----+-----------------+---------------+--------------+---------------+--------------+
# | 1   | Iris-setosa     | 86.4          | 70.0         | 20.1          | 30.5         |
# | 2   | Iris-setosa     | 1.4           | 0.2          | 4.9           | 3.0          |
# | 3   | Iris-setosa     | 1.3           | 0.2          | 4.7           | 3.2          |
# | 4   | Iris-setosa     | 1.5           | 0.2          | 4.6           | 3.1          |
# | 5   | Iris-setosa     | 1.4           | 0.2          | 5.0           | 3.6          |
# | 6   | Iris-setosa     | 1.7           | 0.4          | 5.4           | 3.9          |
# | 7   | Iris-setosa     | 1.4           | 0.3          | 4.6           | 3.4          |
# | 8   | Iris-setosa     | 1.5           | 0.2          | 5.0           | 3.4          |
# | 9   | Iris-setosa     | 1.4           | 0.2          | 4.4           | 2.9          |
# | 10  | Iris-setosa     | 1.5           | 0.1          | 4.9           | 3.1          |
# | 11  | Iris-setosa     | 1.5           | 0.2          | 5.4           | 3.7          |
# | 12  | Iris-setosa     | 1.6           | 0.2          | 4.8           | 3.4          |
# | 13  | Iris-setosa     | 1.4           | 0.1          | 4.8           | 3.0          |
# | 14  | Iris-setosa     | 1.1           | 0.1          | 4.3           | 3.0          |
# | 15  | Iris-setosa     | 1.2           | 0.2          | 5.8           | 4.0          |
# | 16  | Iris-setosa     | 1.5           | 0.4          | 5.7           | 4.4          |
# | 17  | Iris-setosa     | 1.3           | 0.4          | 5.4           | 3.9          |
# | 18  | Iris-setosa     | 1.4           | 0.3          | 5.1           | 3.5          |
# | 19  | Iris-setosa     | 1.7           | 0.3          | 5.7           | 3.8          |
# | 20  | Iris-setosa     | 1.5           | 0.3          | 5.1           | 3.8          |
# | 21  | Iris-setosa     | 1.7           | 0.2          | 5.4           | 3.4          |
# | 22  | Iris-setosa     | 1.5           | 0.4          | 5.1           | 3.7          |
# | 23  | Iris-setosa     | 1.0           | 0.2          | 4.6           | 3.6          |
# | 24  | Iris-setosa     | 1.7           | 0.5          | 5.1           | 3.3          |
# | 25  | Iris-setosa     | 1.9           | 0.2          | 4.8           | 3.4          |
# | 26  | Iris-setosa     | 1.6           | 0.2          | 5.0           | 3.0          |
# | 27  | Iris-setosa     | 1.6           | 0.4          | 5.0           | 3.4          |
# | 28  | Iris-setosa     | 1.5           | 0.2          | 5.2           | 3.5          |
# | 29  | Iris-setosa     | 1.4           | 0.2          | 5.2           | 3.4          |
# | 30  | Iris-setosa     | 1.6           | 0.2          | 4.7           | 3.2          |
# | 31  | Iris-setosa     | 1.6           | 0.2          | 4.8           | 3.1          |
# | 32  | Iris-setosa     | 1.5           | 0.4          | 5.4           | 3.4          |
# | 33  | Iris-setosa     | 1.5           | 0.1          | 5.2           | 4.1          |
# | 34  | Iris-setosa     | 1.4           | 0.2          | 5.5           | 4.2          |
# | 35  | Iris-setosa     | 1.5           | 0.1          | 4.9           | 3.1          |
# | 36  | Iris-setosa     | 1.2           | 0.2          | 5.0           | 3.2          |
# | 37  | Iris-setosa     | 1.3           | 0.2          | 5.5           | 3.5          |
# | 38  | Iris-setosa     | 1.5           | 0.1          | 4.9           | 3.1          |
# | 39  | Iris-setosa     | 1.3           | 0.2          | 4.4           | 3.0          |
# | 40  | Iris-setosa     | 1.5           | 0.2          | 5.1           | 3.4          |
# | 41  | Iris-setosa     | 1.3           | 0.3          | 5.0           | 3.5          |
# | 42  | Iris-setosa     | 1.3           | 0.3          | 4.5           | 2.3          |
# | 43  | Iris-setosa     | 1.3           | 0.2          | 4.4           | 3.2          |
# | 44  | Iris-setosa     | 1.6           | 0.6          | 5.0           | 3.5          |
# | 45  | Iris-setosa     | 1.9           | 0.4          | 5.1           | 3.8          |
# | 46  | Iris-setosa     | 1.4           | 0.3          | 4.8           | 3.0          |
# | 47  | Iris-setosa     | 1.6           | 0.2          | 5.1           | 3.8          |
# | 48  | Iris-setosa     | 1.4           | 0.2          | 4.6           | 3.2          |
# | 49  | Iris-setosa     | 1.5           | 0.2          | 5.3           | 3.7          |
# | 50  | Iris-setosa     | 1.4           | 0.2          | 5.0           | 3.3          |
# | 51  | Iris-versicolor | 4.7           | 1.4          | 7.0           | 3.2          |
# | 52  | Iris-versicolor | 4.5           | 1.5          | 6.4           | 3.2          |
# | 53  | Iris-versicolor | 4.9           | 1.5          | 6.9           | 3.1          |
# | 54  | Iris-versicolor | 4.0           | 1.3          | 5.5           | 2.3          |
# | 55  | Iris-versicolor | 4.6           | 1.5          | 6.5           | 2.8          |
# | 56  | Iris-versicolor | 4.5           | 1.3          | 5.7           | 2.8          |
# | 57  | Iris-versicolor | 4.7           | 1.6          | 6.3           | 3.3          |
# | 58  | Iris-versicolor | 3.3           | 1.0          | 4.9           | 2.4          |
# | 59  | Iris-versicolor | 4.6           | 1.3          | 6.6           | 2.9          |
# | 60  | Iris-versicolor | 3.9           | 1.4          | 5.2           | 2.7          |
# | 61  | Iris-versicolor | 3.5           | 1.0          | 5.0           | 2.0          |
# | 62  | Iris-versicolor | 4.2           | 1.5          | 5.9           | 3.0          |
# | 63  | Iris-versicolor | 4.0           | 1.0          | 6.0           | 2.2          |
# | 64  | Iris-versicolor | 4.7           | 1.4          | 6.1           | 2.9          |
# | 65  | Iris-versicolor | 3.6           | 1.3          | 5.6           | 2.9          |
# | 66  | Iris-versicolor | 4.4           | 1.4          | 6.7           | 3.1          |
# | 67  | Iris-versicolor | 4.5           | 1.5          | 5.6           | 3.0          |
# | 68  | Iris-versicolor | 4.1           | 1.0          | 5.8           | 2.7          |
# | 69  | Iris-versicolor | 4.5           | 1.5          | 6.2           | 2.2          |
# | 70  | Iris-versicolor | 3.9           | 1.1          | 5.6           | 2.5          |
# | 71  | Iris-versicolor | 4.8           | 1.8          | 5.9           | 3.2          |
# | 72  | Iris-versicolor | 4.0           | 1.3          | 6.1           | 2.8          |
# | 73  | Iris-versicolor | 4.9           | 1.5          | 6.3           | 2.5          |
# | 74  | Iris-versicolor | 4.7           | 1.2          | 6.1           | 2.8          |
# | 75  | Iris-versicolor | 4.3           | 1.3          | 6.4           | 2.9          |
# | 76  | Iris-versicolor | 4.4           | 1.4          | 6.6           | 3.0          |
# | 77  | Iris-versicolor | 4.8           | 1.4          | 6.8           | 2.8          |
# | 78  | Iris-versicolor | 5.0           | 1.7          | 6.7           | 3.0          |
# | 79  | Iris-versicolor | 4.5           | 1.5          | 6.0           | 2.9          |
# | 80  | Iris-versicolor | 3.5           | 1.0          | 5.7           | 2.6          |
# | 81  | Iris-versicolor | 3.8           | 1.1          | 5.5           | 2.4          |
# | 82  | Iris-versicolor | 3.7           | 1.0          | 5.5           | 2.4          |
# | 83  | Iris-versicolor | 3.9           | 1.2          | 5.8           | 2.7          |
# | 84  | Iris-versicolor | 5.1           | 1.6          | 6.0           | 2.7          |
# | 85  | Iris-versicolor | 4.5           | 1.5          | 5.4           | 3.0          |
# | 86  | Iris-versicolor | 4.5           | 1.6          | 6.0           | 3.4          |
# | 87  | Iris-versicolor | 4.7           | 1.5          | 6.7           | 3.1          |
# | 88  | Iris-versicolor | 4.4           | 1.3          | 6.3           | 2.3          |
# | 89  | Iris-versicolor | 4.1           | 1.3          | 5.6           | 3.0          |
# | 90  | Iris-versicolor | 4.0           | 1.3          | 5.5           | 2.5          |
# | 91  | Iris-versicolor | 4.4           | 1.2          | 5.5           | 2.6          |
# | 92  | Iris-versicolor | 4.6           | 1.4          | 6.1           | 3.0          |
# | 93  | Iris-versicolor | 4.0           | 1.2          | 5.8           | 2.6          |
# | 94  | Iris-versicolor | 3.3           | 1.0          | 5.0           | 2.3          |
# | 95  | Iris-versicolor | 4.2           | 1.3          | 5.6           | 2.7          |
# | 96  | Iris-versicolor | 4.2           | 1.2          | 5.7           | 3.0          |
# | 97  | Iris-versicolor | 4.2           | 1.3          | 5.7           | 2.9          |
# | 98  | Iris-versicolor | 4.3           | 1.3          | 6.2           | 2.9          |
# | 99  | Iris-versicolor | 3.0           | 1.1          | 5.1           | 2.5          |
# | 100 | Iris-versicolor | 4.1           | 1.3          | 5.7           | 2.8          |
# | 101 | Iris-virginica  | 6.0           | 2.5          | 6.3           | 3.3          |
# | 102 | Iris-virginica  | 5.1           | 1.9          | 5.8           | 2.7          |
# | 103 | Iris-virginica  | 5.9           | 2.1          | 7.1           | 3.0          |
# | 104 | Iris-virginica  | 5.6           | 1.8          | 6.3           | 2.9          |
# | 105 | Iris-virginica  | 5.8           | 2.2          | 6.5           | 3.0          |
# | 106 | Iris-virginica  | 6.6           | 2.1          | 7.6           | 3.0          |
# | 107 | Iris-virginica  | 4.5           | 1.7          | 4.9           | 2.5          |
# | 108 | Iris-virginica  | 6.3           | 1.8          | 7.3           | 2.9          |
# | 109 | Iris-virginica  | 5.8           | 1.8          | 6.7           | 2.5          |
# | 110 | Iris-virginica  | 6.1           | 2.5          | 7.2           | 3.6          |
# | 111 | Iris-virginica  | 5.1           | 2.0          | 6.5           | 3.2          |
# | 112 | Iris-virginica  | 5.3           | 1.9          | 6.4           | 2.7          |
# | 113 | Iris-virginica  | 5.5           | 2.1          | 6.8           | 3.0          |
# | 114 | Iris-virginica  | 5.0           | 2.0          | 5.7           | 2.5          |
# | 115 | Iris-virginica  | 5.1           | 2.4          | 5.8           | 2.8          |
# | 116 | Iris-virginica  | 5.3           | 2.3          | 6.4           | 3.2          |
# | 117 | Iris-virginica  | 5.5           | 1.8          | 6.5           | 3.0          |
# | 118 | Iris-virginica  | 6.7           | 2.2          | 7.7           | 3.8          |
# | 119 | Iris-virginica  | 6.9           | 2.3          | 7.7           | 2.6          |
# | 120 | Iris-virginica  | 5.0           | 1.5          | 6.0           | 2.2          |
# | 121 | Iris-virginica  | 5.7           | 2.3          | 6.9           | 3.2          |
# | 122 | Iris-virginica  | 4.9           | 2.0          | 5.6           | 2.8          |
# | 123 | Iris-virginica  | 6.7           | 2.0          | 7.7           | 2.8          |
# | 124 | Iris-virginica  | 4.9           | 1.8          | 6.3           | 2.7          |
# | 125 | Iris-virginica  | 5.7           | 2.1          | 6.7           | 3.3          |
# | 126 | Iris-virginica  | 6.0           | 1.8          | 7.2           | 3.2          |
# | 127 | Iris-virginica  | 4.8           | 1.8          | 6.2           | 2.8          |
# | 128 | Iris-virginica  | 4.9           | 1.8          | 6.1           | 3.0          |
# | 129 | Iris-virginica  | 5.6           | 2.1          | 6.4           | 2.8          |
# | 130 | Iris-virginica  | 5.8           | 1.6          | 7.2           | 3.0          |
# | 131 | Iris-virginica  | 6.1           | 1.9          | 7.4           | 2.8          |
# | 132 | Iris-virginica  | 6.4           | 2.0          | 7.9           | 3.8          |
# | 133 | Iris-virginica  | 5.6           | 2.2          | 6.4           | 2.8          |
# | 134 | Iris-virginica  | 5.1           | 1.5          | 6.3           | 2.8          |
# | 135 | Iris-virginica  | 5.6           | 1.4          | 6.1           | 2.6          |
# | 136 | Iris-virginica  | 6.1           | 2.3          | 7.7           | 3.0          |
# | 137 | Iris-virginica  | 5.6           | 2.4          | 6.3           | 3.4          |
# | 138 | Iris-virginica  | 5.5           | 1.8          | 6.4           | 3.1          |
# | 139 | Iris-virginica  | 4.8           | 1.8          | 6.0           | 3.0          |
# | 140 | Iris-virginica  | 5.4           | 2.1          | 6.9           | 3.1          |
# | 141 | Iris-virginica  | 5.6           | 2.4          | 6.7           | 3.1          |
# | 142 | Iris-virginica  | 5.1           | 2.3          | 6.9           | 3.1          |
# | 143 | Iris-virginica  | 5.1           | 1.9          | 5.8           | 2.7          |
# | 144 | Iris-virginica  | 5.9           | 2.3          | 6.8           | 3.2          |
# | 145 | Iris-virginica  | 5.7           | 2.5          | 6.7           | 3.3          |
# | 146 | Iris-virginica  | 5.2           | 2.3          | 6.7           | 3.0          |
# | 147 | Iris-virginica  | 5.0           | 1.9          | 6.3           | 2.5          |
# | 148 | Iris-virginica  | 5.2           | 2.0          | 6.5           | 3.0          |
# | 149 | Iris-virginica  | 5.4           | 2.3          | 6.2           | 3.4          |
# | 150 | Iris-virginica  | 5.1           | 1.8          | 5.9           | 3.0          |
# +-----+-----------------+---------------+--------------+---------------+--------------+

# %% [markdown]
# ### 3️⃣ Mencari dan menghapus Outlier 🔍
# - **Outlier** adalah nilai ekstrem yang bisa mengganggu proses klasifikasi, terutama dalam model probabilistik seperti **Naïve Bayes**.
#  maka dari itu kita harus mencari outlier dan menghapus outliernya

# %%
from sklearn.neighbors import LocalOutlierFactor
from tabulate import tabulate

# Menggunakan LocalOutlierFactor untuk deteksi outlier
model = LocalOutlierFactor(n_neighbors=20, contamination=0.01)
X = data_asli[['petal length', 'petal width', 'sepal_length', 'sepal_width']]
outliers = model.fit_predict(X)

# Hasil prediksi (-1 untuk outlier, 1 untuk normal)
data_asli['outlier'] = outliers
data_bersih = data_asli[data_asli['outlier'] == 1].drop(columns=['outlier'])

# Reset index setelah menghapus outlier
data_bersih = data_bersih.reset_index(drop=True)

# Menampilkan hasil setelah membersihkan outlier
print(f"Jumlah data setelah membersihkan outlier: {len(data_bersih)}")
print(tabulate(data_bersih, headers='keys', tablefmt='grid'))
# Out:
# Jumlah data setelah membersihkan outlier: 148
# +-----+------+-----------------+----------------+---------------+----------------+---------------+
# |     |   id | class           |   petal length |   petal width |   sepal_length |   sepal_width |
# +=====+======+=================+================+===============+================+===============+
# |   0 |    2 | Iris-setosa     |            1.4 |           0.2 |            4.9 |           3   |
# +-----+------+-----------------+----------------+---------------+----------------+---------------+
# |   1 |    3 | Iris-setosa     |            1.3 |           0.2 |            4.7 |           3.2 |
# +-----+------+-----------------+----------------+---------------+----------------+---------------+
# |   2 |    4 | Iris-setosa     |            1.5 |           0.2 |            4.6 |           3.1 |
# +-----+------+-----------------+----------------+---------------+----------------+---------------+
# |   3 |    5 | Iris-setosa     |            1.4 |           0.2 |            5   |           3.6 |
# +-----+------+-----------------+----------------+---------------+----------------+---------------+
# |   4 |    6 | Iris-setosa     |            1.7 |           0.4 |            5.4 |           3.9 |
# +-----+------+-----------------+----------------+---------------+----------------+---------------+
# |   5 |    7 | Iris-setosa     |            1.4 |           0.3 |            4.6 |           3.4 |
# +-----+------+-----------------+----------------+---------------+----------------+---------------+
# |   6 |    8 | Iris-setosa     |            1.5 |           0.2 |            5   |           3.4 |
# +-----+------+-----------------+----------------+---------------+----------------+---------------+
# |   7 |    9 | Iris-setosa     |            1.4 |           0.2 |            4.4 |           2.9 |
# +-----+------+-----------------+----------------+---------------+----------------+---------------+
# |   8 |   10 | Iris-setosa     |            1.5 |           0.1 |            4.9 |           3.1 |
# +-----+------+-----------------+----------------+---------------+----------------+---------------+
# |   9 |   11 | Iris-setosa     |            1.5 |           0.2 |            5.4 |           3.7 |
# +-----+------+-----------------+----------------+---------------+----------------+---------------+
# |  10 |   12 | Iris-setosa     |            1.6 |           0.2 |            4.8 |           3.4 |
# +-----+------+-----------------+----------------+---------------+----------------+---------------+
# |  11 |   13 | Iris-setosa     |            1.4 |           0.1 |            4.8 |           3   |
# +-----+------+-----------------+----------------+---------------+----------------+---------------+
# |  12 |   14 | Iris-setosa     |            1.1 |           0.1 |            4.3 |           3   |
# +-----+------+-----------------+----------------+---------------+----------------+---------------+
# |  13 |   15 | Iris-setosa     |            1.2 |           0.2 |            5.8 |           4   |
# +-----+------+-----------------+----------------+---------------+----------------+---------------+
# |  14 |   16 | Iris-setosa     |            1.5 |           0.4 |            5.7 |           4.4 |
# +-----+------+-----------------+----------------+---------------+----------------+---------------+
# |  15 |   17 | Iris-setosa     |            1.3 |           0.4 |            5.4 |           3.9 |
# +-----+------+-----------------+----------------+---------------+----------------+---------------+
# |  16 |   18 | Iris-setosa     |            1.4 |           0.3 |            5.1 |           3.5 |
# +-----+------+-----------------+----------------+---------------+----------------+---------------+
# |  17 |   19 | Iris-setosa     |            1.7 |           0.3 |            5.7 |           3.8 |
# +-----+------+-----------------+----------------+---------------+----------------+---------------+
# |  18 |   20 | Iris-setosa     |            1.5 |           0.3 |            5.1 |           3.8 |
# +-----+------+-----------------+----------------+---------------+----------------+---------------+
# |  19 |   21 | Iris-setosa     |            1.7 |           0.2 |            5.4 |           3.4 |
# +-----+------+-----------------+----------------+---------------+----------------+---------------+
# |  20 |   22 | Iris-setosa     |            1.5 |           0.4 |            5.1 |           3.7 |
# +-----+------+-----------------+----------------+---------------+----------------+---------------+
# |  21 |   23 | Iris-setosa     |            1   |           0.2 |            4.6 |           3.6 |
# +-----+------+-----------------+----------------+---------------+----------------+---------------+
# |  22 |   24 | Iris-setosa     |            1.7 |           0.5 |            5.1 |           3.3 |
# +-----+------+-----------------+----------------+---------------+----------------+---------------+
# |  23 |   25 | Iris-setosa     |            1.9 |           0.2 |            4.8 |           3.4 |
# +-----+------+-----------------+----------------+---------------+----------------+---------------+
# |  24 |   26 | Iris-setosa     |            1.6 |           0.2 |            5   |           3   |
# +-----+------+-----------------+----------------+---------------+----------------+---------------+
# |  25 |   27 | Iris-setosa     |            1.6 |           0.4 |            5   |           3.4 |
# +-----+------+-----------------+----------------+---------------+----------------+---------------+
# |  26 |   28 | Iris-setosa     |            1.5 |           0.2 |            5.2 |           3.5 |
# +-----+------+-----------------+----------------+---------------+----------------+---------------+
# |  27 |   29 | Iris-setosa     |            1.4 |           0.2 |            5.2 |           3.4 |
# +-----+------+-----------------+----------------+---------------+----------------+---------------+
# |  28 |   30 | Iris-setosa     |            1.6 |           0.2 |            4.7 |           3.2 |
# +-----+------+-----------------+----------------+---------------+----------------+---------------+
# |  29 |   31 | Iris-setosa     |            1.6 |           0.2 |            4.8 |           3.1 |
# +-----+------+-----------------+----------------+---------------+----------------+---------------+
# |  30 |   32 | Iris-setosa     |            1.5 |           0.4 |            5.4 |           3.4 |
# +-----+------+-----------------+----------------+---------------+----------------+---------------+
# |  31 |   33 | Iris-setosa     |            1.5 |           0.1 |            5.2 |           4.1 |
# +-----+------+-----------------+----------------+---------------+----------------+---------------+
# |  32 |   34 | Iris-setosa     |            1.4 |           0.2 |            5.5 |           4.2 |
# +-----+------+-----------------+----------------+---------------+----------------+---------------+
# |  33 |   35 | Iris-setosa     |            1.5 |           0.1 |            4.9 |           3.1 |
# +-----+------+-----------------+----------------+---------------+----------------+---------------+
# |  34 |   36 | Iris-setosa     |            1.2 |           0.2 |            5   |           3.2 |
# +-----+------+-----------------+----------------+---------------+----------------+---------------+
# |  35 |   37 | Iris-setosa     |            1.3 |           0.2 |            5.5 |           3.5 |
# +-----+------+-----------------+----------------+---------------+----------------+---------------+
# |  36 |   38 | Iris-setosa     |            1.5 |           0.1 |            4.9 |           3.1 |
# +-----+------+-----------------+----------------+---------------+----------------+---------------+
# |  37 |   39 | Iris-setosa     |            1.3 |           0.2 |            4.4 |           3   |
# +-----+------+-----------------+----------------+---------------+----------------+---------------+
# |  38 |   40 | Iris-setosa     |            1.5 |           0.2 |            5.1 |           3.4 |
# +-----+------+-----------------+----------------+---------------+----------------+---------------+
# |  39 |   41 | Iris-setosa     |            1.3 |           0.3 |            5   |           3.5 |
# +-----+------+-----------------+----------------+---------------+----------------+---------------+
# |  40 |   43 | Iris-setosa     |            1.3 |           0.2 |            4.4 |           3.2 |
# +-----+------+-----------------+----------------+---------------+----------------+---------------+
# |  41 |   44 | Iris-setosa     |            1.6 |           0.6 |            5   |           3.5 |
# +-----+------+-----------------+----------------+---------------+----------------+---------------+
# |  42 |   45 | Iris-setosa     |            1.9 |           0.4 |            5.1 |           3.8 |
# +-----+------+-----------------+----------------+---------------+----------------+---------------+
# |  43 |   46 | Iris-setosa     |            1.4 |           0.3 |            4.8 |           3   |
# +-----+------+-----------------+----------------+---------------+----------------+---------------+
# |  44 |   47 | Iris-setosa     |            1.6 |           0.2 |            5.1 |           3.8 |
# +-----+------+-----------------+----------------+---------------+----------------+---------------+
# |  45 |   48 | Iris-setosa     |            1.4 |           0.2 |            4.6 |           3.2 |
# +-----+------+-----------------+----------------+---------------+----------------+---------------+
# |  46 |   49 | Iris-setosa     |            1.5 |           0.2 |            5.3 |           3.7 |
# +-----+------+-----------------+----------------+---------------+----------------+---------------+
# |  47 |   50 | Iris-setosa     |            1.4 |           0.2 |            5   |           3.3 |
# +-----+------+-----------------+----------------+---------------+----------------+---------------+
# |  48 |   51 | Iris-versicolor |            4.7 |           1.4 |            7   |           3.2 |
# +-----+------+-----------------+----------------+---------------+----------------+---------------+
# |  49 |   52 | Iris-versicolor |            4.5 |           1.5 |            6.4 |           3.2 |
# +-----+------+-----------------+----------------+---------------+----------------+---------------+
# |  50 |   53 | Iris-versicolor |            4.9 |           1.5 |            6.9 |           3.1 |
# +-----+------+-----------------+----------------+---------------+----------------+---------------+
# |  51 |   54 | Iris-versicolor |            4   |           1.3 |            5.5 |           2.3 |
# +-----+------+-----------------+----------------+---------------+----------------+---------------+
# |  52 |   55 | Iris-versicolor |            4.6 |           1.5 |            6.5 |           2.8 |
# +-----+------+-----------------+----------------+---------------+----------------+---------------+
# |  53 |   56 | Iris-versicolor |            4.5 |           1.3 |            5.7 |           2.8 |
# +-----+------+-----------------+----------------+---------------+----------------+---------------+
# |  54 |   57 | Iris-versicolor |            4.7 |           1.6 |            6.3 |           3.3 |
# +-----+------+-----------------+----------------+---------------+----------------+---------------+
# |  55 |   58 | Iris-versicolor |            3.3 |           1   |            4.9 |           2.4 |
# +-----+------+-----------------+----------------+---------------+----------------+---------------+
# |  56 |   59 | Iris-versicolor |            4.6 |           1.3 |            6.6 |           2.9 |
# +-----+------+-----------------+----------------+---------------+----------------+---------------+
# |  57 |   60 | Iris-versicolor |            3.9 |           1.4 |            5.2 |           2.7 |
# +-----+------+-----------------+----------------+---------------+----------------+---------------+
# |  58 |   61 | Iris-versicolor |            3.5 |           1   |            5   |           2   |
# +-----+------+-----------------+----------------+---------------+----------------+---------------+
# |  59 |   62 | Iris-versicolor |            4.2 |           1.5 |            5.9 |           3   |
# +-----+------+-----------------+----------------+---------------+----------------+---------------+
# |  60 |   63 | Iris-versicolor |            4   |           1   |            6   |           2.2 |
# +-----+------+-----------------+----------------+---------------+----------------+---------------+
# |  61 |   64 | Iris-versicolor |            4.7 |           1.4 |            6.1 |           2.9 |
# +-----+------+-----------------+----------------+---------------+----------------+---------------+
# |  62 |   65 | Iris-versicolor |            3.6 |           1.3 |            5.6 |           2.9 |
# +-----+------+-----------------+----------------+---------------+----------------+---------------+
# |  63 |   66 | Iris-versicolor |            4.4 |           1.4 |            6.7 |           3.1 |
# +-----+------+-----------------+----------------+---------------+----------------+---------------+
# |  64 |   67 | Iris-versicolor |            4.5 |           1.5 |            5.6 |           3   |
# +-----+------+-----------------+----------------+---------------+----------------+---------------+
# |  65 |   68 | Iris-versicolor |            4.1 |           1   |            5.8 |           2.7 |
# +-----+------+-----------------+----------------+---------------+----------------+---------------+
# |  66 |   69 | Iris-versicolor |            4.5 |           1.5 |            6.2 |           2.2 |
# +-----+------+-----------------+----------------+---------------+----------------+---------------+
# |  67 |   70 | Iris-versicolor |            3.9 |           1.1 |            5.6 |           2.5 |
# +-----+------+-----------------+----------------+---------------+----------------+---------------+
# |  68 |   71 | Iris-versicolor |            4.8 |           1.8 |            5.9 |           3.2 |
# +-----+------+-----------------+----------------+---------------+----------------+---------------+
# |  69 |   72 | Iris-versicolor |            4   |           1.3 |            6.1 |           2.8 |
# +-----+------+-----------------+----------------+---------------+----------------+---------------+
# |  70 |   73 | Iris-versicolor |            4.9 |           1.5 |            6.3 |           2.5 |
# +-----+------+-----------------+----------------+---------------+----------------+---------------+
# |  71 |   74 | Iris-versicolor |            4.7 |           1.2 |            6.1 |           2.8 |
# +-----+------+-----------------+----------------+---------------+----------------+---------------+
# |  72 |   75 | Iris-versicolor |            4.3 |           1.3 |            6.4 |           2.9 |
# +-----+------+-----------------+----------------+---------------+----------------+---------------+
# |  73 |   76 | Iris-versicolor |            4.4 |           1.4 |            6.6 |           3   |
# +-----+------+-----------------+----------------+---------------+----------------+---------------+
# |  74 |   77 | Iris-versicolor |            4.8 |           1.4 |            6.8 |           2.8 |
# +-----+------+-----------------+----------------+---------------+----------------+---------------+
# |  75 |   78 | Iris-versicolor |            5   |           1.7 |            6.7 |           3   |
# +-----+------+-----------------+----------------+---------------+----------------+---------------+
# |  76 |   79 | Iris-versicolor |            4.5 |           1.5 |            6   |           2.9 |
# +-----+------+-----------------+----------------+---------------+----------------+---------------+
# |  77 |   80 | Iris-versicolor |            3.5 |           1   |            5.7 |           2.6 |
# +-----+------+-----------------+----------------+---------------+----------------+---------------+
# |  78 |   81 | Iris-versicolor |            3.8 |           1.1 |            5.5 |           2.4 |
# +-----+------+-----------------+----------------+---------------+----------------+---------------+
# |  79 |   82 | Iris-versicolor |            3.7 |           1   |            5.5 |           2.4 |
# +-----+------+-----------------+----------------+---------------+----------------+---------------+
# |  80 |   83 | Iris-versicolor |            3.9 |           1.2 |            5.8 |           2.7 |
# +-----+------+-----------------+----------------+---------------+----------------+---------------+
# |  81 |   84 | Iris-versicolor |            5.1 |           1.6 |            6   |           2.7 |
# +-----+------+-----------------+----------------+---------------+----------------+---------------+
# |  82 |   85 | Iris-versicolor |            4.5 |           1.5 |            5.4 |           3   |
# +-----+------+-----------------+----------------+---------------+----------------+---------------+
# |  83 |   86 | Iris-versicolor |            4.5 |           1.6 |            6   |           3.4 |
# +-----+------+-----------------+----------------+---------------+----------------+---------------+
# |  84 |   87 | Iris-versicolor |            4.7 |           1.5 |            6.7 |           3.1 |
# +-----+------+-----------------+----------------+---------------+----------------+---------------+
# |  85 |   88 | Iris-versicolor |            4.4 |           1.3 |            6.3 |           2.3 |
# +-----+------+-----------------+----------------+---------------+----------------+---------------+
# |  86 |   89 | Iris-versicolor |            4.1 |           1.3 |            5.6 |           3   |
# +-----+------+-----------------+----------------+---------------+----------------+---------------+
# |  87 |   90 | Iris-versicolor |            4   |           1.3 |            5.5 |           2.5 |
# +-----+------+-----------------+----------------+---------------+----------------+---------------+
# |  88 |   91 | Iris-versicolor |            4.4 |           1.2 |            5.5 |           2.6 |
# +-----+------+-----------------+----------------+---------------+----------------+---------------+
# |  89 |   92 | Iris-versicolor |            4.6 |           1.4 |            6.1 |           3   |
# +-----+------+-----------------+----------------+---------------+----------------+---------------+
# |  90 |   93 | Iris-versicolor |            4   |           1.2 |            5.8 |           2.6 |
# +-----+------+-----------------+----------------+---------------+----------------+---------------+
# |  91 |   94 | Iris-versicolor |            3.3 |           1   |            5   |           2.3 |
# +-----+------+-----------------+----------------+---------------+----------------+---------------+
# |  92 |   95 | Iris-versicolor |            4.2 |           1.3 |            5.6 |           2.7 |
# +-----+------+-----------------+----------------+---------------+----------------+---------------+
# |  93 |   96 | Iris-versicolor |            4.2 |           1.2 |            5.7 |           3   |
# +-----+------+-----------------+----------------+---------------+----------------+---------------+
# |  94 |   97 | Iris-versicolor |            4.2 |           1.3 |            5.7 |           2.9 |
# +-----+------+-----------------+----------------+---------------+----------------+---------------+
# |  95 |   98 | Iris-versicolor |            4.3 |           1.3 |            6.2 |           2.9 |
# +-----+------+-----------------+----------------+---------------+----------------+---------------+
# |  96 |   99 | Iris-versicolor |            3   |           1.1 |            5.1 |           2.5 |
# +-----+------+-----------------+----------------+---------------+----------------+---------------+
# |  97 |  100 | Iris-versicolor |            4.1 |           1.3 |            5.7 |           2.8 |
# +-----+------+-----------------+----------------+---------------+----------------+---------------+
# |  98 |  101 | Iris-virginica  |            6   |           2.5 |            6.3 |           3.3 |
# +-----+------+-----------------+----------------+---------------+----------------+---------------+
# |  99 |  102 | Iris-virginica  |            5.1 |           1.9 |            5.8 |           2.7 |
# +-----+------+-----------------+----------------+---------------+----------------+---------------+
# | 100 |  103 | Iris-virginica  |            5.9 |           2.1 |            7.1 |           3   |
# +-----+------+-----------------+----------------+---------------+----------------+---------------+
# | 101 |  104 | Iris-virginica  |            5.6 |           1.8 |            6.3 |           2.9 |
# +-----+------+-----------------+----------------+---------------+----------------+---------------+
# | 102 |  105 | Iris-virginica  |            5.8 |           2.2 |            6.5 |           3   |
# +-----+------+-----------------+----------------+---------------+----------------+---------------+
# | 103 |  106 | Iris-virginica  |            6.6 |           2.1 |            7.6 |           3   |
# +-----+------+-----------------+----------------+---------------+----------------+---------------+
# | 104 |  107 | Iris-virginica  |            4.5 |           1.7 |            4.9 |           2.5 |
# +-----+------+-----------------+----------------+---------------+----------------+---------------+
# | 105 |  108 | Iris-virginica  |            6.3 |           1.8 |            7.3 |           2.9 |
# +-----+------+-----------------+----------------+---------------+----------------+---------------+
# | 106 |  109 | Iris-virginica  |            5.8 |           1.8 |            6.7 |           2.5 |
# +-----+------+-----------------+----------------+---------------+----------------+---------------+
# | 107 |  110 | Iris-virginica  |            6.1 |           2.5 |            7.2 |           3.6 |
# +-----+------+-----------------+----------------+---------------+----------------+---------------+
# | 108 |  111 | Iris-virginica  |            5.1 |           2   |            6.5 |           3.2 |
# +-----+------+-----------------+----------------+---------------+----------------+---------------+
# | 109 |  112 | Iris-virginica  |            5.3 |           1.9 |            6.4 |           2.7 |
# +-----+------+-----------------+----------------+---------------+----------------+---------------+
# | 110 |  113 | Iris-virginica  |            5.5 |           2.1 |            6.8 |           3   |
# +-----+------+-----------------+----------------+---------------+----------------+---------------+
# | 111 |  114 | Iris-virginica  |            5   |           2   |            5.7 |           2.5 |
# +-----+------+-----------------+----------------+---------------+----------------+---------------+
# | 112 |  115 | Iris-virginica  |            5.1 |           2.4 |            5.8 |           2.8 |
# +-----+------+-----------------+----------------+---------------+----------------+---------------+
# | 113 |  116 | Iris-virginica  |            5.3 |           2.3 |            6.4 |           3.2 |
# +-----+------+-----------------+----------------+---------------+----------------+---------------+
# | 114 |  117 | Iris-virginica  |            5.5 |           1.8 |            6.5 |           3   |
# +-----+------+-----------------+----------------+---------------+----------------+---------------+
# | 115 |  118 | Iris-virginica  |            6.7 |           2.2 |            7.7 |           3.8 |
# +-----+------+-----------------+----------------+---------------+----------------+---------------+
# | 116 |  119 | Iris-virginica  |            6.9 |           2.3 |            7.7 |           2.6 |
# +-----+------+-----------------+----------------+---------------+----------------+---------------+
# | 117 |  120 | Iris-virginica  |            5   |           1.5 |            6   |           2.2 |
# +-----+------+-----------------+----------------+---------------+----------------+---------------+
# | 118 |  121 | Iris-virginica  |            5.7 |           2.3 |            6.9 |           3.2 |
# +-----+------+-----------------+----------------+---------------+----------------+---------------+
# | 119 |  122 | Iris-virginica  |            4.9 |           2   |            5.6 |           2.8 |
# +-----+------+-----------------+----------------+---------------+----------------+---------------+
# | 120 |  123 | Iris-virginica  |            6.7 |           2   |            7.7 |           2.8 |
# +-----+------+-----------------+----------------+---------------+----------------+---------------+
# | 121 |  124 | Iris-virginica  |            4.9 |           1.8 |            6.3 |           2.7 |
# +-----+------+-----------------+----------------+---------------+----------------+---------------+
# | 122 |  125 | Iris-virginica  |            5.7 |           2.1 |            6.7 |           3.3 |
# +-----+------+-----------------+----------------+---------------+----------------+---------------+
# | 123 |  126 | Iris-virginica  |            6   |           1.8 |            7.2 |           3.2 |
# +-----+------+-----------------+----------------+---------------+----------------+---------------+
# | 124 |  127 | Iris-virginica  |            4.8 |           1.8 |            6.2 |           2.8 |
# +-----+------+-----------------+----------------+---------------+----------------+---------------+
# | 125 |  128 | Iris-virginica  |            4.9 |           1.8 |            6.1 |           3   |
# +-----+------+-----------------+----------------+---------------+----------------+---------------+
# | 126 |  129 | Iris-virginica  |            5.6 |           2.1 |            6.4 |           2.8 |
# +-----+------+-----------------+----------------+---------------+----------------+---------------+
# | 127 |  130 | Iris-virginica  |            5.8 |           1.6 |            7.2 |           3   |
# +-----+------+-----------------+----------------+---------------+----------------+---------------+
# | 128 |  131 | Iris-virginica  |            6.1 |           1.9 |            7.4 |           2.8 |
# +-----+------+-----------------+----------------+---------------+----------------+---------------+
# | 129 |  132 | Iris-virginica  |            6.4 |           2   |            7.9 |           3.8 |
# +-----+------+-----------------+----------------+---------------+----------------+---------------+
# | 130 |  133 | Iris-virginica  |            5.6 |           2.2 |            6.4 |           2.8 |
# +-----+------+-----------------+----------------+---------------+----------------+---------------+
# | 131 |  134 | Iris-virginica  |            5.1 |           1.5 |            6.3 |           2.8 |
# +-----+------+-----------------+----------------+---------------+----------------+---------------+
# | 132 |  135 | Iris-virginica  |            5.6 |           1.4 |            6.1 |           2.6 |
# +-----+------+-----------------+----------------+---------------+----------------+---------------+
# | 133 |  136 | Iris-virginica  |            6.1 |           2.3 |            7.7 |           3   |
# +-----+------+-----------------+----------------+---------------+----------------+---------------+
# | 134 |  137 | Iris-virginica  |            5.6 |           2.4 |            6.3 |           3.4 |
# +-----+------+-----------------+----------------+---------------+----------------+---------------+
# | 135 |  138 | Iris-virginica  |            5.5 |           1.8 |            6.4 |           3.1 |
# +-----+------+-----------------+----------------+---------------+----------------+---------------+
# | 136 |  139 | Iris-virginica  |            4.8 |           1.8 |            6   |           3   |
# +-----+------+-----------------+----------------+---------------+----------------+---------------+
# | 137 |  140 | Iris-virginica  |            5.4 |           2.1 |            6.9 |           3.1 |
# +-----+------+-----------------+----------------+---------------+----------------+---------------+
# | 138 |  141 | Iris-virginica  |            5.6 |           2.4 |            6.7 |           3.1 |
# +-----+------+-----------------+----------------+---------------+----------------+---------------+
# | 139 |  142 | Iris-virginica  |            5.1 |           2.3 |            6.9 |           3.1 |
# +-----+------+-----------------+----------------+---------------+----------------+---------------+
# | 140 |  143 | Iris-virginica  |            5.1 |           1.9 |            5.8 |           2.7 |
# +-----+------+-----------------+----------------+---------------+----------------+---------------+
# | 141 |  144 | Iris-virginica  |            5.9 |           2.3 |            6.8 |           3.2 |
# +-----+------+-----------------+----------------+---------------+----------------+---------------+
# | 142 |  145 | Iris-virginica  |            5.7 |           2.5 |            6.7 |           3.3 |
# +-----+------+-----------------+----------------+---------------+----------------+---------------+
# | 143 |  146 | Iris-virginica  |            5.2 |           2.3 |            6.7 |           3   |
# +-----+------+-----------------+----------------+---------------+----------------+---------------+
# | 144 |  147 | Iris-virginica  |            5   |           1.9 |            6.3 |           2.5 |
# +-----+------+-----------------+----------------+---------------+----------------+---------------+
# | 145 |  148 | Iris-virginica  |            5.2 |           2   |            6.5 |           3   |
# +-----+------+-----------------+----------------+---------------+----------------+---------------+
# | 146 |  149 | Iris-virginica  |            5.4 |           2.3 |            6.2 |           3.4 |
# +-----+------+-----------------+----------------+---------------+----------------+---------------+
# | 147 |  150 | Iris-virginica  |            5.1 |           1.8 |            5.9 |           3   |
# +-----+------+-----------------+----------------+---------------+----------------+---------------+

# %% [markdown]
# # 🌟 **Langkah-langkah Perhitungan Naïve Bayes** 📊
#
# ## 📌 1. **Persiapan Dataset** 📂
# Naïve Bayes menghitung probabilitas suatu kelas berdasarkan fitur yang diberikan. Misalnya, kita memiliki dataset bunga iris dengan fitur:
# - **Petal Length** (Panjang Kelopak)
# - **Petal Width** (Lebar Kelopak)
# - **Class** (Jenis bunga: Iris-setosa, Iris-versicolor, Iris-virginica)
#
# Kita akan menghitung probabilitas menggunakan Naïve Bayes berdasarkan dataset ini.
#
# ---
#
# ## 📌 2. **Menghitung Prior Probability \( P(Kelas) \)** 🧮
# Prior probability adalah probabilitas awal dari setiap kelas sebelum mempertimbangkan fitur.
#
# $$
# P(\text{Iris-setosa}) = \frac{\text{Jumlah Iris-setosa}}{\text{Total Data}}
# $$
#
# $$
# P(\text{Iris-versicolor}) = \frac{\text{Jumlah Iris-versicolor}}{\text{Total Data}}
# $$
#
# $$
# P(\text{Iris-virginica}) = \frac{\text{Jumlah Iris-virginica}}{\text{Total Data}}
# $$
#
# ---
#
# ## 📌 3. **Menghitung Likelihood \( P(Fitur | Kelas) \)** 📊
# Untuk setiap fitur (misalnya petal length), kita menghitung distribusi probabilitas dalam masing-masing kelas dengan distribusi normal:
#
# $$
# P(X | Kelas) = \frac{1}{\sqrt{2\pi\sigma^2}} \exp \left( -\frac{(X - \mu)^2}{2\sigma^2} \right)
# $$
#
# Di mana:
# - \( \mu \) adalah **mean** dari fitur dalam kelas tertentu
# - \( \sigma^2 \) adalah **variance** dari fitur dalam kelas tertentu
# - \( X \) adalah nilai fitur yang diamati
#
# Contoh perhitungan untuk **Petal Length** dalam kelas **Iris-setosa**:
#
# $$
# \mu_{\text{setosa}} = \frac{\sum \text{Petal Length Setosa}}{\text{Jumlah Setosa}}
# $$
#
# $$
# \sigma^2_{\text{setosa}} = \frac{\sum (X - \mu_{\text{setosa}})^2}{\text{Jumlah Setosa}}
# $$
#
# ---
#
# ## 📌 4. **Menghitung Posterior Probability \( P(Kelas | Fitur) \)** 🤔
# Posterior probability dihitung menggunakan **Teorema Bayes**:
#
# $$
# P(Kelas | X) = \frac{P(X | Kelas) P(Kelas)}{P(X)}
# $$
#
# Karena \( P(X) \) sama untuk semua kelas, kita cukup membandingkan nilai **numerator**:
#
# $$
# P(Kelas | X) \propto P(X | Kelas) P(Kelas)
# $$
#
# ---
#
# ## 📌 5. **Menentukan Kelas dengan Probabilitas Tertinggi** 🏆
# Kita memilih kelas yang memiliki **posterior probability** tertinggi sebagai prediksi akhir.
#
# $$
# \text{Prediksi} = \arg\max P(Kelas | X)
# $$
#
# ---
# berikuy code nya

# %%
import pandas as pd
import numpy as np
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import accuracy_score
from tabulate import tabulate

# Pilih fitur numerik untuk model Naïve Bayes
numeric_cols = ["sepal_length", "sepal_width", "petal length", "petal width"]
X_full = data_asli[numeric_cols]
y_full = data_asli["class"]

# Inisialisasi model Naïve Bayes
nb_full = GaussianNB()

# Latih model dengan data **tanpa menghapus outlier**
nb_full.fit(X_full, y_full)

# Hitung likelihood P(X|Y) untuk setiap sampel
likelihoods_full = nb_full.predict_proba(X_full)

# Konversi likelihood menjadi DataFrame untuk setiap kelas
likelihood_df_full = pd.DataFrame(likelihoods_full, columns=nb_full.classes_)

# Gabungkan hasil likelihood dengan dataset utama
data_asli = pd.concat([data_asli, likelihood_df_full], axis=1)

# Tambahkan hasil akhir prediksi ke dataset
data_asli["final_prediction"] = nb_full.predict(X_full)

# Hapus kolom class_frequency agar sesuai dengan dataset tanpa outlier
if "class_frequency" in data_asli.columns:
    data_asli = data_asli.drop(columns=["class_frequency"])

# Urutkan ulang kolom agar sesuai dengan versi tanpa outlier
ordered_columns = ["id", "sepal length", "sepal width", "petal length", "petal width",
                   "class"] + list(nb_full.classes_) + ["final_prediction"]

# Pastikan hanya kolom yang ada di dataset yang dipilih
data_asli = data_asli[[col for col in ordered_columns if col in data_asli.columns]]

# Hitung akurasi
accuracy = accuracy_score(y_full, data_asli["final_prediction"])

# Tampilkan hasil akhir dalam bentuk tabel dan akurasi
print("Hasil Naïve Bayes **tanpa menghapus outlier**:")
print(tabulate(data_asli, headers="keys", tablefmt="psql", showindex=False))
# Out:
# Hasil Naïve Bayes **tanpa menghapus outlier**:
# +------+----------------+---------------+-----------------+---------------+-------------------+------------------+--------------------+
# |   id |   petal length |   petal width | class           |   Iris-setosa |   Iris-versicolor |   Iris-virginica | final_prediction   |
# |------+----------------+---------------+-----------------+---------------+-------------------+------------------+--------------------|
# |    1 |           86.4 |          70   | Iris-setosa     |   1           |       0           |      0           | Iris-setosa        |
# |    2 |            1.4 |           0.2 | Iris-setosa     |   1           |       2.78223e-12 |      4.31289e-20 | Iris-setosa        |
# |    3 |            1.3 |           0.2 | Iris-setosa     |   1           |       1.55044e-13 |      3.38143e-21 | Iris-setosa        |
# |    4 |            1.5 |           0.2 | Iris-setosa     |   1           |       2.00939e-12 |      4.04965e-20 | Iris-setosa        |
# |    5 |            1.4 |           0.2 | Iris-setosa     |   1           |       1.45234e-13 |      9.23994e-21 | Iris-setosa        |
# |    6 |            1.7 |           0.4 | Iris-setosa     |   1           |       1.89233e-10 |      2.23068e-17 | Iris-setosa        |
# |    7 |            1.4 |           0.3 | Iris-setosa     |   1           |       2.01344e-12 |      4.95119e-20 | Iris-setosa        |
# |    8 |            1.5 |           0.2 | Iris-setosa     |   1           |       2.42823e-12 |      1.03028e-19 | Iris-setosa        |
# |    9 |            1.4 |           0.2 | Iris-setosa     |   1           |       3.09002e-13 |      3.94989e-21 | Iris-setosa        |
# |   10 |            1.5 |           0.1 | Iris-setosa     |   1           |       3.52447e-13 |      1.24312e-20 | Iris-setosa        |
# |   11 |            1.5 |           0.2 | Iris-setosa     |   1           |       6.51905e-13 |      7.5419e-20  | Iris-setosa        |
# |   12 |            1.6 |           0.2 | Iris-setosa     |   1           |       3.90586e-12 |      1.70767e-19 | Iris-setosa        |
# |   13 |            1.4 |           0.1 | Iris-setosa     |   1           |       8.63158e-14 |      2.22409e-21 | Iris-setosa        |
# |   14 |            1.1 |           0.1 | Iris-setosa     |   1           |       1.02031e-16 |      2.45544e-24 | Iris-setosa        |
# |   15 |            1.2 |           0.2 | Iris-setosa     |   1           |       6.90857e-16 |      2.33652e-22 | Iris-setosa        |
# |   16 |            1.5 |           0.4 | Iris-setosa     |   1           |       2.02945e-14 |      1.10932e-20 | Iris-setosa        |
# |   17 |            1.3 |           0.4 | Iris-setosa     |   1           |       1.15723e-12 |      9.8245e-20  | Iris-setosa        |
# |   18 |            1.4 |           0.3 | Iris-setosa     |   1           |       7.55056e-12 |      2.63759e-19 | Iris-setosa        |
# |   19 |            1.7 |           0.3 | Iris-setosa     |   1           |       7.2024e-11  |      1.21955e-17 | Iris-setosa        |
# |   20 |            1.5 |           0.3 | Iris-setosa     |   1           |       1.78036e-12 |      1.41452e-19 | Iris-setosa        |
# |   21 |            1.7 |           0.2 | Iris-setosa     |   1           |       8.66295e-11 |      5.84066e-18 | Iris-setosa        |
# |   22 |            1.5 |           0.4 | Iris-setosa     |   1           |       6.27491e-11 |      2.92365e-18 | Iris-setosa        |
# |   23 |            1   |           0.2 | Iris-setosa     |   1           |       9.36233e-17 |      4.68405e-24 | Iris-setosa        |
# |   24 |            1.7 |           0.5 | Iris-setosa     |   1           |       1.5e-07     |      2.76869e-15 | Iris-setosa        |
# |   25 |            1.9 |           0.2 | Iris-setosa     |   1           |       1.26361e-10 |      7.77335e-18 | Iris-setosa        |
# |   26 |            1.6 |           0.2 | Iris-setosa     |   1           |       5.15009e-11 |      9.74957e-19 | Iris-setosa        |
# |   27 |            1.6 |           0.4 | Iris-setosa     |   1           |       1.78981e-09 |      4.18323e-17 | Iris-setosa        |
# |   28 |            1.5 |           0.2 | Iris-setosa     |   1           |       2.24876e-12 |      1.3517e-19  | Iris-setosa        |
# |   29 |            1.4 |           0.2 | Iris-setosa     |   1           |       1.24761e-12 |      5.48189e-20 | Iris-setosa        |
# |   30 |            1.6 |           0.2 | Iris-setosa     |   1           |       7.59796e-12 |      2.07957e-19 | Iris-setosa        |
# |   31 |            1.6 |           0.2 | Iris-setosa     |   1           |       1.76253e-11 |      3.90449e-19 | Iris-setosa        |
# |   32 |            1.5 |           0.4 | Iris-setosa     |   1           |       1.56709e-09 |      4.4078e-17  | Iris-setosa        |
# |   33 |            1.5 |           0.1 | Iris-setosa     |   1           |       1.72124e-16 |      8.21985e-23 | Iris-setosa        |
# |   34 |            1.4 |           0.2 | Iris-setosa     |   1           |       4.7597e-16  |      2.1272e-22  | Iris-setosa        |
# |   35 |            1.5 |           0.1 | Iris-setosa     |   1           |       3.52447e-13 |      1.24312e-20 | Iris-setosa        |
# |   36 |            1.2 |           0.2 | Iris-setosa     |   1           |       1.30592e-13 |      2.89918e-21 | Iris-setosa        |
# |   37 |            1.3 |           0.2 | Iris-setosa     |   1           |       3.15308e-13 |      2.14823e-20 | Iris-setosa        |
# |   38 |            1.5 |           0.1 | Iris-setosa     |   1           |       3.52447e-13 |      1.24312e-20 | Iris-setosa        |
# |   39 |            1.3 |           0.2 | Iris-setosa     |   1           |       6.64485e-14 |      9.83981e-22 | Iris-setosa        |
# |   40 |            1.5 |           0.2 | Iris-setosa     |   1           |       3.39028e-12 |      1.51041e-19 | Iris-setosa        |
# |   41 |            1.3 |           0.3 | Iris-setosa     |   1           |       1.41118e-12 |      4.40815e-20 | Iris-setosa        |
# |   42 |            1.3 |           0.3 | Iris-setosa     |   1           |       8.50366e-13 |      2.10355e-21 | Iris-setosa        |
# |   43 |            1.3 |           0.2 | Iris-setosa     |   1           |       3.31377e-14 |      7.59413e-22 | Iris-setosa        |
# |   44 |            1.6 |           0.6 | Iris-setosa     |   1           |       6.55076e-08 |      1.61862e-15 | Iris-setosa        |
# |   45 |            1.9 |           0.4 | Iris-setosa     |   1           |       2.56574e-09 |      2.36935e-16 | Iris-setosa        |
# |   46 |            1.4 |           0.3 | Iris-setosa     |   1           |       3.06749e-11 |      3.09988e-19 | Iris-setosa        |
# |   47 |            1.6 |           0.2 | Iris-setosa     |   1           |       3.7599e-13  |      4.89371e-20 | Iris-setosa        |
# |   48 |            1.4 |           0.2 | Iris-setosa     |   1           |       3.68312e-13 |      8.58453e-21 | Iris-setosa        |
# |   49 |            1.5 |           0.2 | Iris-setosa     |   1           |       5.20353e-13 |      5.5129e-20  | Iris-setosa        |
# |   50 |            1.4 |           0.2 | Iris-setosa     |   1           |       1.21541e-12 |      3.79047e-20 | Iris-setosa        |
# |   51 |            4.7 |           1.4 | Iris-versicolor |   0.000333502 |       0.803769    |      0.195897    | Iris-versicolor    |
# |   52 |            4.5 |           1.5 | Iris-versicolor |   8.22567e-05 |       0.945092    |      0.0548259   | Iris-versicolor    |
# |   53 |            4.9 |           1.5 | Iris-versicolor |   0.000202676 |       0.456059    |      0.543739    | Iris-virginica     |
# |   54 |            4   |           1.3 | Iris-versicolor |   7.34197e-05 |       0.999895    |      3.12467e-05 | Iris-versicolor    |
# |   55 |            4.6 |           1.5 | Iris-versicolor |   4.22136e-05 |       0.952402    |      0.0475562   | Iris-versicolor    |
# |   56 |            4.5 |           1.3 | Iris-versicolor |   1.82992e-05 |       0.999101    |      0.000880359 | Iris-versicolor    |
# |   57 |            4.7 |           1.6 | Iris-versicolor |   0.000202812 |       0.658819    |      0.340978    | Iris-versicolor    |
# |   58 |            3.3 |           1   | Iris-versicolor |   0.00728832  |       0.992711    |      2.31508e-07 | Iris-versicolor    |
# |   59 |            4.6 |           1.3 | Iris-versicolor |   4.01906e-05 |       0.990276    |      0.00968333  | Iris-versicolor    |
# |   60 |            3.9 |           1.4 | Iris-versicolor |   6.03434e-05 |       0.999849    |      9.02484e-05 | Iris-versicolor    |
# |   61 |            3.5 |           1   | Iris-versicolor |   0.0226445   |       0.977355    |      2.29746e-07 | Iris-versicolor    |
# |   62 |            4.2 |           1.5 | Iris-versicolor |   2.7846e-05  |       0.996211    |      0.00376161  | Iris-versicolor    |
# |   63 |            4   |           1   | Iris-versicolor |   0.000328546 |       0.999665    |      6.01437e-06 | Iris-versicolor    |
# |   64 |            4.7 |           1.4 | Iris-versicolor |   2.58537e-05 |       0.986065    |      0.0139088   | Iris-versicolor    |
# |   65 |            3.6 |           1.3 | Iris-versicolor |   5.4286e-05  |       0.999921    |      2.46114e-05 | Iris-versicolor    |
# |   66 |            4.4 |           1.4 | Iris-versicolor |   7.08252e-05 |       0.979968    |      0.0199616   | Iris-versicolor    |
# |   67 |            4.5 |           1.5 | Iris-versicolor |   3.98883e-05 |       0.990648    |      0.00931237  | Iris-versicolor    |
# |   68 |            4.1 |           1   | Iris-versicolor |   6.30944e-05 |       0.999921    |      1.63363e-05 | Iris-versicolor    |
# |   69 |            4.5 |           1.5 | Iris-versicolor |   0.000129558 |       0.994568    |      0.00530221  | Iris-versicolor    |
# |   70 |            3.9 |           1.1 | Iris-versicolor |   6.65618e-05 |       0.999926    |      6.99321e-06 | Iris-versicolor    |
# |   71 |            4.8 |           1.8 | Iris-versicolor |   0.000211545 |       0.154462    |      0.845327    | Iris-virginica     |
# |   72 |            4   |           1.3 | Iris-versicolor |   1.69041e-05 |       0.99979     |      0.000192971 | Iris-versicolor    |
# |   73 |            4.9 |           1.5 | Iris-versicolor |   8.3927e-05  |       0.926999    |      0.0729169   | Iris-versicolor    |
# |   74 |            4.7 |           1.2 | Iris-versicolor |   2.73592e-05 |       0.998129    |      0.00184344  | Iris-versicolor    |
# |   75 |            4.3 |           1.3 | Iris-versicolor |   2.13532e-05 |       0.998439    |      0.00153916  | Iris-versicolor    |
# |   76 |            4.4 |           1.4 | Iris-versicolor |   4.15638e-05 |       0.98743     |      0.0125284   | Iris-versicolor    |
# |   77 |            4.8 |           1.4 | Iris-versicolor |   9.12353e-05 |       0.912761    |      0.0871477   | Iris-versicolor    |
# |   78 |            5   |           1.7 | Iris-versicolor |   7.86083e-05 |       0.0752633   |      0.924658    | Iris-virginica     |
# |   79 |            4.5 |           1.5 | Iris-versicolor |   2.54561e-05 |       0.986455    |      0.0135194   | Iris-versicolor    |
# |   80 |            3.5 |           1   | Iris-versicolor |   0.00027556  |       0.999723    |      1.23761e-06 | Iris-versicolor    |
# |   81 |            3.8 |           1.1 | Iris-versicolor |   0.000129333 |       0.999867    |      3.55207e-06 | Iris-versicolor    |
# |   82 |            3.7 |           1   | Iris-versicolor |   0.000336242 |       0.999662    |      1.34879e-06 | Iris-versicolor    |
# |   83 |            3.9 |           1.2 | Iris-versicolor |   2.47259e-05 |       0.999948    |      2.76518e-05 | Iris-versicolor    |
# |   84 |            5.1 |           1.6 | Iris-versicolor |   0.000116333 |       0.612089    |      0.387795    | Iris-versicolor    |
# |   85 |            4.5 |           1.5 | Iris-versicolor |   5.62774e-05 |       0.992421    |      0.00752295  | Iris-versicolor    |
# |   86 |            4.5 |           1.6 | Iris-versicolor |   0.000298673 |       0.875846    |      0.123855    | Iris-versicolor    |
# |   87 |            4.7 |           1.5 | Iris-versicolor |   0.000119004 |       0.7992      |      0.200681    | Iris-versicolor    |
# |   88 |            4.4 |           1.3 | Iris-versicolor |   5.28745e-05 |       0.999333    |      0.000614552 | Iris-versicolor    |
# |   89 |            4.1 |           1.3 | Iris-versicolor |   2.54787e-05 |       0.999771    |      0.000203726 | Iris-versicolor    |
# |   90 |            4   |           1.3 | Iris-versicolor |   3.48425e-05 |       0.99992     |      4.47651e-05 | Iris-versicolor    |
# |   91 |            4.4 |           1.2 | Iris-versicolor |   3.0464e-05  |       0.999843    |      0.000126317 | Iris-versicolor    |
# |   92 |            4.6 |           1.4 | Iris-versicolor |   2.63133e-05 |       0.989345    |      0.0106283   | Iris-versicolor    |
# |   93 |            4   |           1.2 | Iris-versicolor |   2.40319e-05 |       0.999942    |      3.37706e-05 | Iris-versicolor    |
# |   94 |            3.3 |           1   | Iris-versicolor |   0.00769181  |       0.992308    |      2.00931e-07 | Iris-versicolor    |
# |   95 |            4.2 |           1.3 | Iris-versicolor |   1.84443e-05 |       0.999814    |      0.000167669 | Iris-versicolor    |
# |   96 |            4.2 |           1.2 | Iris-versicolor |   2.62386e-05 |       0.999824    |      0.000150122 | Iris-versicolor    |
# |   97 |            4.2 |           1.3 | Iris-versicolor |   1.77385e-05 |       0.999697    |      0.000285049 | Iris-versicolor    |
# |   98 |            4.3 |           1.3 | Iris-versicolor |   1.68821e-05 |       0.998975    |      0.00100762  | Iris-versicolor    |
# |   99 |            3   |           1.1 | Iris-versicolor |   0.00594186  |       0.994058    |      2.29943e-07 | Iris-versicolor    |
# |  100 |            4.1 |           1.3 | Iris-versicolor |   1.70622e-05 |       0.99983     |      0.000152838 | Iris-versicolor    |
# |  101 |            6   |           2.5 | Iris-virginica  |   0.000322589 |       6.3519e-11  |      0.999677    | Iris-virginica     |
# |  102 |            5.1 |           1.9 | Iris-virginica  |   0.000138517 |       0.0250088   |      0.974853    | Iris-virginica     |
# |  103 |            5.9 |           2.1 | Iris-virginica  |   3.71065e-05 |       1.67911e-07 |      0.999963    | Iris-virginica     |
# |  104 |            5.6 |           1.8 | Iris-virginica  |   4.30011e-05 |       0.00199455  |      0.997962    | Iris-virginica     |
# |  105 |            5.8 |           2.2 | Iris-virginica  |   3.5073e-05  |       2.30538e-07 |      0.999965    | Iris-virginica     |
# |  106 |            6.6 |           2.1 | Iris-virginica  |   0.000392991 |       2.40885e-10 |      0.999607    | Iris-virginica     |
# |  107 |            4.5 |           1.7 | Iris-virginica  |   0.00108588  |       0.972457    |      0.0264569   | Iris-versicolor    |
# |  108 |            6.3 |           1.8 | Iris-virginica  |   0.000133229 |       1.34001e-06 |      0.999865    | Iris-virginica     |
# |  109 |            5.8 |           1.8 | Iris-virginica  |   0.000110605 |       0.000492849 |      0.999397    | Iris-virginica     |
# |  110 |            6.1 |           2.5 | Iris-virginica  |   0.00169601  |       1.40333e-12 |      0.998304    | Iris-virginica     |
# |  111 |            5.1 |           2   | Iris-virginica  |   4.78151e-05 |       0.000412867 |      0.999539    | Iris-virginica     |
# |  112 |            5.3 |           1.9 | Iris-virginica  |   4.8046e-05  |       0.0027773   |      0.997175    | Iris-virginica     |
# |  113 |            5.5 |           2.1 | Iris-virginica  |   2.59474e-05 |       4.80704e-06 |      0.999969    | Iris-virginica     |
# |  114 |            5   |           2   | Iris-virginica  |   0.000382155 |       0.0128759   |      0.986742    | Iris-virginica     |
# |  115 |            5.1 |           2.4 | Iris-virginica  |   0.000265277 |       1.04228e-06 |      0.999734    | Iris-virginica     |
# |  116 |            5.3 |           2.3 | Iris-virginica  |   6.6048e-05  |       4.50929e-07 |      0.999934    | Iris-virginica     |
# |  117 |            5.5 |           1.8 | Iris-virginica  |   3.67644e-05 |       0.0018719   |      0.998091    | Iris-virginica     |
# |  118 |            6.7 |           2.2 | Iris-virginica  |   0.0237204   |       1.60674e-12 |      0.97628     | Iris-virginica     |
# |  119 |            6.9 |           2.3 | Iris-virginica  |   0.00493015  |       6.44226e-13 |      0.99507     | Iris-virginica     |
# |  120 |            5   |           1.5 | Iris-virginica  |   0.000351428 |       0.957799    |      0.04185     | Iris-versicolor    |
# |  121 |            5.7 |           2.3 | Iris-virginica  |   5.71609e-05 |       1.17112e-08 |      0.999943    | Iris-virginica     |
# |  122 |            4.9 |           2   | Iris-virginica  |   0.000236419 |       0.0137594   |      0.986004    | Iris-virginica     |
# |  123 |            6.7 |           2   | Iris-virginica  |   0.000776113 |       7.57659e-10 |      0.999224    | Iris-virginica     |
# |  124 |            4.9 |           1.8 | Iris-virginica  |   0.000106477 |       0.129973    |      0.86992     | Iris-virginica     |
# |  125 |            5.7 |           2.1 | Iris-virginica  |   4.51545e-05 |       9.71744e-07 |      0.999954    | Iris-virginica     |
# |  126 |            6   |           1.8 | Iris-virginica  |   8.26986e-05 |       7.39845e-06 |      0.99991     | Iris-virginica     |
# |  127 |            4.8 |           1.8 | Iris-virginica  |   0.000111599 |       0.199906    |      0.799982    | Iris-virginica     |
# |  128 |            4.9 |           1.8 | Iris-virginica  |   9.81205e-05 |       0.107473    |      0.892429    | Iris-virginica     |
# |  129 |            5.6 |           2.1 | Iris-virginica  |   3.26235e-05 |       1.09465e-05 |      0.999956    | Iris-virginica     |
# |  130 |            5.8 |           1.6 | Iris-virginica  |   0.000122513 |       0.000701721 |      0.999176    | Iris-virginica     |
# |  131 |            6.1 |           1.9 | Iris-virginica  |   8.874e-05   |       9.06164e-07 |      0.99991     | Iris-virginica     |
# |  132 |            6.4 |           2   | Iris-virginica  |   0.0120152   |       2.93168e-10 |      0.987985    | Iris-virginica     |
# |  133 |            5.6 |           2.2 | Iris-virginica  |   3.8561e-05  |       1.50784e-06 |      0.99996     | Iris-virginica     |
# |  134 |            5.1 |           1.5 | Iris-virginica  |   9.02135e-05 |       0.712581    |      0.287329    | Iris-versicolor    |
# |  135 |            5.6 |           1.4 | Iris-virginica  |   0.00052894  |       0.485942    |      0.513529    | Iris-virginica     |
# |  136 |            6.1 |           2.3 | Iris-virginica  |   0.00020748  |       8.98407e-11 |      0.999793    | Iris-virginica     |
# |  137 |            5.6 |           2.4 | Iris-virginica  |   0.00019095  |       6.58735e-09 |      0.999809    | Iris-virginica     |
# |  138 |            5.5 |           1.8 | Iris-virginica  |   4.23121e-05 |       0.0019022   |      0.998055    | Iris-virginica     |
# |  139 |            4.8 |           1.8 | Iris-virginica  |   0.000130787 |       0.193159    |      0.80671     | Iris-virginica     |
# |  140 |            5.4 |           2.1 | Iris-virginica  |   3.01186e-05 |       5.23116e-06 |      0.999965    | Iris-virginica     |
# |  141 |            5.6 |           2.4 | Iris-virginica  |   6.88691e-05 |       5.01421e-09 |      0.999931    | Iris-virginica     |
# |  142 |            5.1 |           2.3 | Iris-virginica  |   6.55384e-05 |       4.67774e-07 |      0.999934    | Iris-virginica     |
# |  143 |            5.1 |           1.9 | Iris-virginica  |   0.000138517 |       0.0250088   |      0.974853    | Iris-virginica     |
# |  144 |            5.9 |           2.3 | Iris-virginica  |   6.50941e-05 |       4.42534e-09 |      0.999935    | Iris-virginica     |
# |  145 |            5.7 |           2.5 | Iris-virginica  |   0.000198298 |       1.64574e-10 |      0.999802    | Iris-virginica     |
# |  146 |            5.2 |           2.3 | Iris-virginica  |   5.05961e-05 |       5.85487e-07 |      0.999949    | Iris-virginica     |
# |  147 |            5   |           1.9 | Iris-virginica  |   0.000156849 |       0.0254419   |      0.974401    | Iris-virginica     |
# |  148 |            5.2 |           2   | Iris-virginica  |   3.22094e-05 |       0.000370158 |      0.999598    | Iris-virginica     |
# |  149 |            5.4 |           2.3 | Iris-virginica  |   0.000142385 |       2.45989e-07 |      0.999857    | Iris-virginica     |
# |  150 |            5.1 |           1.8 | Iris-virginica  |   9.91715e-05 |       0.0559996   |      0.943901    | Iris-virginica     |
# +------+----------------+---------------+-----------------+---------------+-------------------+------------------+--------------------+

# %%
print(f"\nAkurasi Model Naïve Bayes: {accuracy * 100:.2f}%")
# Out:
# Akurasi Model Naïve Bayes: 96.00%

# %%
import pandas as pd
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import precision_score, recall_score, f1_score, confusion_matrix, roc_auc_score, log_loss, accuracy_score
from tabulate import tabulate

# Asumsi data_bersih sudah ada setelah menghapus outlier
# Pilih fitur numerik untuk model Naïve Bayes
numeric_cols = ["sepal_length", "sepal_width", "petal length", "petal width"]
X_bersih = data_bersih[numeric_cols]
y_bersih = data_bersih["class"]

# Tangani NaN (opsi 1: menghapus baris yang memiliki NaN)
X_bersih = X_bersih.dropna()
y_bersih = y_bersih[X_bersih.index]  # Sesuaikan y dengan index X

# Inisialisasi model Naïve Bayes
nb_bersih = GaussianNB()

# Latih model dengan data bersih (tanpa outlier)
nb_bersih.fit(X_bersih, y_bersih)

# Hitung likelihood P(X|Y) untuk setiap sampel
likelihoods_bersih = nb_bersih.predict_proba(X_bersih)

# Konversi likelihood menjadi DataFrame untuk setiap kelas
likelihood_df_bersih = pd.DataFrame(likelihoods_bersih, columns=nb_bersih.classes_)

# Gabungkan hasil likelihood dengan dataset utama
data_bersih = data_bersih.loc[X_bersih.index]  # Menyelaraskan indeks
data_bersih = pd.concat([data_bersih, likelihood_df_bersih], axis=1)

# Tambahkan hasil akhir prediksi ke dataset
data_bersih["final_prediction"] = nb_bersih.predict(X_bersih)

# Hapus kolom class_frequency agar sesuai dengan dataset
if "class_frequency" in data_bersih.columns:
    data_bersih = data_bersih.drop(columns=["class_frequency"])

# Urutkan ulang kolom
ordered_columns = ["id", "sepal_length", "sepal_width", "petal length", "petal width",
                   "class"] + list(nb_bersih.classes_) + ["final_prediction"]

# Pastikan hanya kolom yang ada di dataset yang dipilih
data_bersih = data_bersih[[col for col in ordered_columns if col in data_bersih.columns]]

# Tampilkan hasil akhir dalam bentuk tabel
print("Hasil Naïve Bayes **setelah menghapus outlier**:")
print(tabulate(data_bersih, headers="keys", tablefmt="psql", showindex=False))

# Hitung akurasi model
accuracy = accuracy_score(y_bersih, data_bersih["final_prediction"])
print(f"\nAkurasi Model Naïve Bayes: {accuracy:.4f}")
# Out:
# Hasil Naïve Bayes **setelah menghapus outlier**:
# +------+----------------+---------------+----------------+---------------+-----------------+---------------+-------------------+------------------+--------------------+
# |   id |   sepal_length |   sepal_width |   petal length |   petal width | class           |   Iris-setosa |   Iris-versicolor |   Iris-virginica | final_prediction   |
# |------+----------------+---------------+----------------+---------------+-----------------+---------------+-------------------+------------------+--------------------|
# |    2 |            4.9 |           3   |            1.4 |           0.2 | Iris-setosa     |  1            |       1.77375e-17 |      2.7496e-25  | Iris-setosa        |
# |    3 |            4.7 |           3.2 |            1.3 |           0.2 | Iris-setosa     |  1            |       1.18185e-18 |      2.57757e-26 | Iris-setosa        |
# |    4 |            4.6 |           3.1 |            1.5 |           0.2 | Iris-setosa     |  1            |       1.63328e-17 |      3.29166e-25 | Iris-setosa        |
# |    5 |            5   |           3.6 |            1.4 |           0.2 | Iris-setosa     |  1            |       4.56454e-19 |      2.90401e-26 | Iris-setosa        |
# |    6 |            5.4 |           3.9 |            1.7 |           0.4 | Iris-setosa     |  1            |       1.42422e-14 |      1.67887e-21 | Iris-setosa        |
# |    7 |            4.6 |           3.4 |            1.4 |           0.3 | Iris-setosa     |  1            |       1.16849e-17 |      2.87341e-25 | Iris-setosa        |
# |    8 |            5   |           3.4 |            1.5 |           0.2 | Iris-setosa     |  1            |       6.45876e-18 |      2.7404e-25  | Iris-setosa        |
# |    9 |            4.4 |           2.9 |            1.4 |           0.2 | Iris-setosa     |  1            |       1.22538e-17 |      1.56638e-25 | Iris-setosa        |
# |   10 |            4.9 |           3.1 |            1.5 |           0.1 | Iris-setosa     |  1            |       3.45177e-18 |      1.21748e-25 | Iris-setosa        |
# |   11 |            5.4 |           3.7 |            1.5 |           0.2 | Iris-setosa     |  1            |       4.27292e-18 |      4.94337e-25 | Iris-setosa        |
# |   12 |            4.8 |           3.4 |            1.6 |           0.2 | Iris-setosa     |  1            |       1.61748e-17 |      7.07176e-25 | Iris-setosa        |
# |   13 |            4.8 |           3   |            1.4 |           0.1 | Iris-setosa     |  1            |       1.39542e-18 |      3.59559e-26 | Iris-setosa        |
# |   14 |            4.3 |           3   |            1.1 |           0.1 | Iris-setosa     |  1            |       9.11626e-20 |      2.19391e-27 | Iris-setosa        |
# |   15 |            5.8 |           4   |            1.2 |           0.2 | Iris-setosa     |  1            |       2.73757e-19 |      9.25869e-26 | Iris-setosa        |
# |   16 |            5.7 |           4.4 |            1.5 |           0.4 | Iris-setosa     |  1            |       4.34933e-17 |      2.37741e-23 | Iris-setosa        |
# |   17 |            5.4 |           3.9 |            1.3 |           0.4 | Iris-setosa     |  1            |       5.7199e-17  |      4.85603e-24 | Iris-setosa        |
# |   18 |            5.1 |           3.5 |            1.4 |           0.3 | Iris-setosa     |  1            |       2.36442e-17 |      8.2595e-25  | Iris-setosa        |
# |   19 |            5.7 |           3.8 |            1.7 |           0.3 | Iris-setosa     |  1            |       5.72911e-15 |      9.70088e-22 | Iris-setosa        |
# |   20 |            5.1 |           3.8 |            1.5 |           0.3 | Iris-setosa     |  1            |       8.87131e-18 |      7.04842e-25 | Iris-setosa        |
# |   21 |            5.4 |           3.4 |            1.7 |           0.2 | Iris-setosa     |  1            |       1.02883e-15 |      6.93653e-23 | Iris-setosa        |
# |   22 |            5.1 |           3.7 |            1.5 |           0.4 | Iris-setosa     |  1            |       6.03944e-16 |      2.81394e-23 | Iris-setosa        |
# |   23 |            4.6 |           3.6 |            1   |           0.2 | Iris-setosa     |  1            |       2.02974e-20 |      1.0155e-27  | Iris-setosa        |
# |   24 |            5.1 |           3.3 |            1.7 |           0.5 | Iris-setosa     |  1            |       1.65462e-11 |      3.0541e-19  | Iris-setosa        |
# |   25 |            4.8 |           3.4 |            1.9 |           0.2 | Iris-setosa     |  1            |       8.68653e-15 |      5.34371e-22 | Iris-setosa        |
# |   26 |            5   |           3   |            1.6 |           0.2 | Iris-setosa     |  1            |       3.87127e-16 |      7.3287e-24  | Iris-setosa        |
# |   27 |            5   |           3.4 |            1.6 |           0.4 | Iris-setosa     |  1            |       1.64794e-14 |      3.85166e-22 | Iris-setosa        |
# |   28 |            5.2 |           3.5 |            1.5 |           0.2 | Iris-setosa     |  1            |       7.03291e-18 |      4.2274e-25  | Iris-setosa        |
# |   29 |            5.2 |           3.4 |            1.4 |           0.2 | Iris-setosa     |  1            |       4.09816e-18 |      1.8007e-25  | Iris-setosa        |
# |   30 |            4.7 |           3.2 |            1.6 |           0.2 | Iris-setosa     |  1            |       4.82092e-17 |      1.3195e-24  | Iris-setosa        |
# |   31 |            4.8 |           3.1 |            1.6 |           0.2 | Iris-setosa     |  1            |       1.14843e-16 |      2.5441e-24  | Iris-setosa        |
# |   32 |            5.4 |           3.4 |            1.5 |           0.4 | Iris-setosa     |  1            |       2.04663e-14 |      5.75665e-22 | Iris-setosa        |
# |   33 |            5.2 |           4.1 |            1.5 |           0.1 | Iris-setosa     |  1            |       7.17708e-21 |      3.42748e-27 | Iris-setosa        |
# |   34 |            5.5 |           4.2 |            1.4 |           0.2 | Iris-setosa     |  1            |       3.86533e-20 |      1.7275e-26  | Iris-setosa        |
# |   35 |            4.9 |           3.1 |            1.5 |           0.1 | Iris-setosa     |  1            |       3.45177e-18 |      1.21748e-25 | Iris-setosa        |
# |   36 |            5   |           3.2 |            1.2 |           0.2 | Iris-setosa     |  1            |       1.41096e-18 |      3.13239e-26 | Iris-setosa        |
# |   37 |            5.5 |           3.5 |            1.3 |           0.2 | Iris-setosa     |  1            |       3.55342e-18 |      2.421e-25   | Iris-setosa        |
# |   38 |            4.9 |           3.1 |            1.5 |           0.1 | Iris-setosa     |  1            |       3.45177e-18 |      1.21748e-25 | Iris-setosa        |
# |   39 |            4.4 |           3   |            1.3 |           0.2 | Iris-setosa     |  1            |       2.6295e-18  |      3.89383e-26 | Iris-setosa        |
# |   40 |            5.1 |           3.4 |            1.5 |           0.2 | Iris-setosa     |  1            |       9.33693e-18 |      4.15972e-25 | Iris-setosa        |
# |   41 |            5   |           3.5 |            1.3 |           0.3 | Iris-setosa     |  1            |       6.32698e-18 |      1.97639e-25 | Iris-setosa        |
# |   43 |            4.4 |           3.2 |            1.3 |           0.2 | Iris-setosa     |  1            |       7.58917e-19 |      1.73921e-26 | Iris-setosa        |
# |   44 |            5   |           3.5 |            1.6 |           0.6 | Iris-setosa     |  1            |       5.02239e-11 |      1.24097e-18 | Iris-setosa        |
# |   45 |            5.1 |           3.8 |            1.9 |           0.4 | Iris-setosa     |  1            |       6.95187e-13 |      6.41975e-20 | Iris-setosa        |
# |   46 |            4.8 |           3   |            1.4 |           0.3 | Iris-setosa     |  1            |       2.34367e-16 |      2.36843e-24 | Iris-setosa        |
# |   47 |            5.1 |           3.8 |            1.6 |           0.2 | Iris-setosa     |  1            |       2.32562e-18 |      3.02694e-25 | Iris-setosa        |
# |   48 |            4.6 |           3.2 |            1.4 |           0.2 | Iris-setosa     |  1            |       2.52189e-18 |      5.878e-26   | Iris-setosa        |
# |   49 |            5.3 |           3.7 |            1.5 |           0.2 | Iris-setosa     |  1            |       2.58887e-18 |      2.74281e-25 | Iris-setosa        |
# |   50 |            5   |           3.3 |            1.4 |           0.2 | Iris-setosa     |  1            |       3.68405e-18 |      1.14895e-25 | Iris-setosa        |
# |   51 |            7   |           3.2 |            4.7 |           1.4 | Iris-versicolor |  5.42523e-106 |       0.804038    |      0.195962    | Iris-versicolor    |
# |   52 |            6.4 |           3.2 |            4.5 |           1.5 | Iris-versicolor |  1.61944e-98  |       0.94517     |      0.0548304   | Iris-versicolor    |
# |   53 |            6.9 |           3.1 |            4.9 |           1.5 | Iris-versicolor |  9.25092e-120 |       0.456151    |      0.543849    | Iris-virginica     |
# |   54 |            5.5 |           2.3 |            4   |           1.3 | Iris-versicolor |  4.56507e-69  |       0.999969    |      3.12489e-05 | Iris-versicolor    |
# |   55 |            6.5 |           2.8 |            4.6 |           1.5 | Iris-versicolor |  2.23396e-104 |       0.952442    |      0.0475582   | Iris-versicolor    |
# |   56 |            5.7 |           2.8 |            4.5 |           1.3 | Iris-versicolor |  1.33104e-88  |       0.99912     |      0.000880373 | Iris-versicolor    |
# |   57 |            6.3 |           3.3 |            4.7 |           1.6 | Iris-versicolor |  1.62595e-111 |       0.658952    |      0.341048    | Iris-versicolor    |
# |   58 |            4.9 |           2.4 |            3.3 |           1   | Iris-versicolor |  4.55549e-34  |       1           |      2.33207e-07 | Iris-versicolor    |
# |   59 |            6.6 |           2.9 |            4.6 |           1.3 | Iris-versicolor |  4.30869e-96  |       0.990316    |      0.00968369  | Iris-versicolor    |
# |   60 |            5.2 |           2.7 |            3.9 |           1.4 | Iris-versicolor |  5.13686e-68  |       0.99991     |      9.02536e-05 | Iris-versicolor    |
# |   61 |            5   |           2   |            3.5 |           1   | Iris-versicolor |  7.04162e-41  |       1           |      2.35068e-07 | Iris-versicolor    |
# |   62 |            5.9 |           3   |            4.2 |           1.5 | Iris-versicolor |  9.54748e-85  |       0.996238    |      0.00376171  | Iris-versicolor    |
# |   63 |            6   |           2.2 |            4   |           1   | Iris-versicolor |  5.61862e-60  |       0.999994    |      6.01632e-06 | Iris-versicolor    |
# |   64 |            6.1 |           2.9 |            4.7 |           1.4 | Iris-versicolor |  1.14316e-102 |       0.986091    |      0.0139092   | Iris-versicolor    |
# |   65 |            5.6 |           2.9 |            3.6 |           1.3 | Iris-versicolor |  3.83298e-54  |       0.999975    |      2.46126e-05 | Iris-versicolor    |
# |   66 |            6.7 |           3.1 |            4.4 |           1.4 | Iris-versicolor |  1.73882e-91  |       0.980037    |      0.019963    | Iris-versicolor    |
# |   67 |            5.6 |           3   |            4.5 |           1.5 | Iris-versicolor |  2.68358e-96  |       0.990687    |      0.00931273  | Iris-versicolor    |
# |   68 |            5.8 |           2.7 |            4.1 |           1   | Iris-versicolor |  4.7075e-62   |       0.999984    |      1.63373e-05 | Iris-versicolor    |
# |   69 |            6.2 |           2.2 |            4.5 |           1.5 | Iris-versicolor |  5.05843e-100 |       0.994697    |      0.00530289  | Iris-versicolor    |
# |   70 |            5.6 |           2.5 |            3.9 |           1.1 | Iris-versicolor |  7.7356e-58   |       0.999993    |      6.99364e-06 | Iris-versicolor    |
# |   71 |            5.9 |           3.2 |            4.8 |           1.8 | Iris-versicolor |  1.17858e-125 |       0.154494    |      0.845506    | Iris-virginica     |
# |   72 |            6.1 |           2.8 |            4   |           1.3 | Iris-versicolor |  8.50615e-70  |       0.999807    |      0.000192974 | Iris-versicolor    |
# |   73 |            6.3 |           2.5 |            4.9 |           1.5 | Iris-versicolor |  3.68815e-118 |       0.927077    |      0.0729229   | Iris-versicolor    |
# |   74 |            6.1 |           2.8 |            4.7 |           1.2 | Iris-versicolor |  5.83337e-95  |       0.998157    |      0.00184348  | Iris-versicolor    |
# |   75 |            6.4 |           2.9 |            4.3 |           1.3 | Iris-versicolor |  2.08636e-82  |       0.998461    |      0.00153918  | Iris-versicolor    |
# |   76 |            6.6 |           3   |            4.4 |           1.4 | Iris-versicolor |  2.7885e-91   |       0.987471    |      0.0125289   | Iris-versicolor    |
# |   77 |            6.8 |           2.8 |            4.8 |           1.4 | Iris-versicolor |  1.36718e-110 |       0.912844    |      0.0871556   | Iris-versicolor    |
# |   78 |            6.7 |           3   |            5   |           1.7 | Iris-versicolor |  3.23316e-134 |       0.0752691   |      0.924731    | Iris-virginica     |
# |   79 |            6   |           2.9 |            4.5 |           1.5 | Iris-versicolor |  9.01848e-98  |       0.98648     |      0.0135197   | Iris-versicolor    |
# |   80 |            5.7 |           2.6 |            3.5 |           1   | Iris-versicolor |  3.14848e-41  |       0.999999    |      1.23794e-06 | Iris-versicolor    |
# |   81 |            5.5 |           2.4 |            3.8 |           1.1 | Iris-versicolor |  2.86402e-54  |       0.999996    |      3.55252e-06 | Iris-versicolor    |
# |   82 |            5.5 |           2.4 |            3.7 |           1   | Iris-versicolor |  1.50925e-47  |       0.999999    |      1.34924e-06 | Iris-versicolor    |
# |   83 |            5.8 |           2.7 |            3.9 |           1.2 | Iris-versicolor |  1.51894e-61  |       0.999972    |      2.76524e-05 | Iris-versicolor    |
# |   84 |            6   |           2.7 |            5.1 |           1.6 | Iris-versicolor |  2.61145e-131 |       0.61216     |      0.38784     | Iris-versicolor    |
# |   85 |            5.4 |           3   |            4.5 |           1.5 | Iris-versicolor |  8.3615e-96   |       0.992477    |      0.00752336  | Iris-versicolor    |
# |   86 |            6   |           3.4 |            4.5 |           1.6 | Iris-versicolor |  4.47663e-101 |       0.876108    |      0.123892    | Iris-versicolor    |
# |   87 |            6.7 |           3.1 |            4.7 |           1.5 | Iris-versicolor |  4.06199e-109 |       0.799295    |      0.200705    | Iris-versicolor    |
# |   88 |            6.3 |           2.3 |            4.4 |           1.3 | Iris-versicolor |  1.75635e-87  |       0.999385    |      0.000614583 | Iris-versicolor    |
# |   89 |            5.6 |           3   |            4.1 |           1.3 | Iris-versicolor |  1.69523e-71  |       0.999796    |      0.00020373  | Iris-versicolor    |
# |   90 |            5.5 |           2.5 |            4   |           1.3 | Iris-versicolor |  1.17284e-68  |       0.999955    |      4.47665e-05 | Iris-versicolor    |
# |   91 |            5.5 |           2.6 |            4.4 |           1.2 | Iris-versicolor |  2.00927e-80  |       0.999874    |      0.00012632  | Iris-versicolor    |
# |   92 |            6.1 |           3   |            4.6 |           1.4 | Iris-versicolor |  6.80084e-98  |       0.989371    |      0.0106285   | Iris-versicolor    |
# |   93 |            5.8 |           2.6 |            4   |           1.2 | Iris-versicolor |  2.02785e-65  |       0.999966    |      3.37713e-05 | Iris-versicolor    |
# |   94 |            5   |           2.3 |            3.3 |           1   | Iris-versicolor |  2.07686e-34  |       1           |      2.02488e-07 | Iris-versicolor    |
# |   95 |            5.6 |           2.7 |            4.2 |           1.3 | Iris-versicolor |  3.92763e-76  |       0.999832    |      0.000167671 | Iris-versicolor    |
# |   96 |            5.7 |           3   |            4.2 |           1.2 | Iris-versicolor |  8.00572e-72  |       0.99985     |      0.000150125 | Iris-versicolor    |
# |   97 |            5.7 |           2.9 |            4.2 |           1.3 | Iris-versicolor |  6.35216e-76  |       0.999715    |      0.000285053 | Iris-versicolor    |
# |   98 |            6.2 |           2.9 |            4.3 |           1.3 | Iris-versicolor |  1.3164e-81   |       0.998992    |      0.00100764  | Iris-versicolor    |
# |   99 |            5.1 |           2.5 |            3   |           1.1 | Iris-versicolor |  1.57426e-29  |       1           |      2.31317e-07 | Iris-versicolor    |
# |  100 |            5.7 |           2.8 |            4.1 |           1.3 | Iris-versicolor |  2.8282e-72   |       0.999847    |      0.00015284  | Iris-versicolor    |
# |  101 |            6.3 |           3.3 |            6   |           2.5 | Iris-virginica  |  6.61961e-245 |       6.35381e-11 |      1           | Iris-virginica     |
# |  102 |            5.8 |           2.7 |            5.1 |           1.9 | Iris-virginica  |  1.73076e-147 |       0.0250122   |      0.974988    | Iris-virginica     |
# |  103 |            7.1 |           3   |            5.9 |           2.1 | Iris-virginica  |  1.11191e-213 |       1.67915e-07 |      1           | Iris-virginica     |
# |  104 |            6.3 |           2.9 |            5.6 |           1.8 | Iris-virginica  |  2.14354e-171 |       0.00199462  |      0.998005    | Iris-virginica     |
# |  105 |            6.5 |           3   |            5.8 |           2.2 | Iris-virginica  |  9.59795e-211 |       2.30543e-07 |      1           | Iris-virginica     |
# |  106 |            7.6 |           3   |            6.6 |           2.1 | Iris-virginica  |  4.424e-265   |       2.40977e-10 |      1           | Iris-virginica     |
# |  107 |            4.9 |           2.5 |            4.5 |           1.7 | Iris-virginica  |  1.29719e-105 |       0.973514    |      0.0264857   | Iris-versicolor    |
# |  108 |            7.3 |           2.9 |            6.3 |           1.8 | Iris-virginica  |  1.82754e-222 |       1.34018e-06 |      0.999999    | Iris-virginica     |
# |  109 |            6.7 |           2.5 |            5.8 |           1.8 | Iris-virginica  |  2.47673e-186 |       0.000492902 |      0.999507    | Iris-virginica     |
# |  110 |            7.2 |           3.6 |            6.1 |           2.5 | Iris-virginica  |  2.74264e-256 |       1.40568e-12 |      1           | Iris-virginica     |
# |  111 |            6.5 |           3.2 |            5.1 |           2   | Iris-virginica  |  2.96506e-156 |       0.000412884 |      0.999587    | Iris-virginica     |
# |  112 |            6.4 |           2.7 |            5.3 |           1.9 | Iris-virginica  |  5.15558e-161 |       0.00277742  |      0.997223    | Iris-virginica     |
# |  113 |            6.8 |           3   |            5.5 |           2.1 | Iris-virginica  |  2.33917e-187 |       4.80712e-06 |      0.999995    | Iris-virginica     |
# |  114 |            5.7 |           2.5 |            5   |           2   | Iris-virginica  |  1.40066e-148 |       0.0128807   |      0.987119    | Iris-virginica     |
# |  115 |            5.8 |           2.8 |            5.1 |           2.4 | Iris-virginica  |  1.46188e-182 |       1.04254e-06 |      0.999999    | Iris-virginica     |
# |  116 |            6.4 |           3.2 |            5.3 |           2.3 | Iris-virginica  |  9.5112e-188  |       4.50952e-07 |      1           | Iris-virginica     |
# |  117 |            6.5 |           3   |            5.5 |           1.8 | Iris-virginica  |  2.27971e-166 |       0.00187197  |      0.998128    | Iris-virginica     |
# |  118 |            7.7 |           3.8 |            6.7 |           2.2 | Iris-virginica  |  1.02757e-278 |       1.64575e-12 |      1           | Iris-virginica     |
# |  119 |            7.7 |           2.6 |            6.9 |           2.3 | Iris-virginica  |  2.68104e-303 |       6.47407e-13 |      1           | Iris-virginica     |
# |  120 |            6   |           2.2 |            5   |           1.5 | Iris-virginica  |  1.59742e-122 |       0.958135    |      0.0418646   | Iris-versicolor    |
# |  121 |            6.9 |           3.2 |            5.7 |           2.3 | Iris-virginica  |  5.75692e-214 |       1.17117e-08 |      1           | Iris-virginica     |
# |  122 |            5.6 |           2.8 |            4.9 |           2   | Iris-virginica  |  1.05871e-142 |       0.0137626   |      0.986237    | Iris-virginica     |
# |  123 |            7.7 |           2.8 |            6.7 |           2   | Iris-virginica  |  8.00551e-267 |       7.5824e-10  |      1           | Iris-virginica     |
# |  124 |            6.3 |           2.7 |            4.9 |           1.8 | Iris-virginica  |  3.19765e-133 |       0.129987    |      0.870013    | Iris-virginica     |
# |  125 |            6.7 |           3.3 |            5.7 |           2.1 | Iris-virginica  |  3.86332e-198 |       9.71778e-07 |      0.999999    | Iris-virginica     |
# |  126 |            7.2 |           3.2 |            6   |           1.8 | Iris-virginica  |  3.38923e-201 |       7.39902e-06 |      0.999993    | Iris-virginica     |
# |  127 |            6.2 |           2.8 |            4.8 |           1.8 | Iris-virginica  |  1.21708e-127 |       0.199928    |      0.800072    | Iris-virginica     |
# |  128 |            6.1 |           3   |            4.9 |           1.8 | Iris-virginica  |  8.38702e-132 |       0.107484    |      0.892516    | Iris-virginica     |
# |  129 |            6.4 |           2.8 |            5.6 |           2.1 | Iris-virginica  |  2.613e-191   |       1.09468e-05 |      0.999989    | Iris-virginica     |
# |  130 |            7.2 |           3   |            5.8 |           1.6 | Iris-virginica  |  1.38619e-177 |       0.000701806 |      0.999298    | Iris-virginica     |
# |  131 |            7.4 |           2.8 |            6.1 |           1.9 | Iris-virginica  |  5.35059e-216 |       9.06238e-07 |      0.999999    | Iris-virginica     |
# |  132 |            7.9 |           3.8 |            6.4 |           2   | Iris-virginica  |  4.42159e-245 |       2.96731e-10 |      1           | Iris-virginica     |
# |  133 |            6.4 |           2.8 |            5.6 |           2.2 | Iris-virginica  |  2.34473e-198 |       1.50788e-06 |      0.999998    | Iris-virginica     |
# |  134 |            6.3 |           2.8 |            5.1 |           1.5 | Iris-virginica  |  1.70603e-127 |       0.712645    |      0.287355    | Iris-versicolor    |
# |  135 |            6.1 |           2.6 |            5.6 |           1.4 | Iris-virginica  |  6.1362e-150  |       0.486199    |      0.513801    | Iris-virginica     |
# |  136 |            7.7 |           3   |            6.1 |           2.3 | Iris-virginica  |  1.21338e-245 |       8.98579e-11 |      1           | Iris-virginica     |
# |  137 |            6.3 |           3.4 |            5.6 |           2.4 | Iris-virginica  |  7.69531e-212 |       6.58849e-09 |      1           | Iris-virginica     |
# |  138 |            6.4 |           3.1 |            5.5 |           1.8 | Iris-virginica  |  1.14477e-165 |       0.00190228  |      0.998098    | Iris-virginica     |
# |  139 |            6   |           3   |            4.8 |           1.8 | Iris-virginica  |  1.97701e-126 |       0.193184    |      0.806816    | Iris-virginica     |
# |  140 |            6.9 |           3.1 |            5.4 |           2.1 | Iris-virginica  |  4.76127e-182 |       5.23126e-06 |      0.999995    | Iris-virginica     |
# |  141 |            6.7 |           3.1 |            5.6 |           2.4 | Iris-virginica  |  1.45671e-214 |       5.01447e-09 |      1           | Iris-virginica     |
# |  142 |            6.9 |           3.1 |            5.1 |           2.3 | Iris-virginica  |  6.12189e-180 |       4.67798e-07 |      1           | Iris-virginica     |
# |  143 |            5.8 |           2.7 |            5.1 |           1.9 | Iris-virginica  |  1.73076e-147 |       0.0250122   |      0.974988    | Iris-virginica     |
# |  144 |            6.8 |           3.2 |            5.9 |           2.3 | Iris-virginica  |  8.87112e-226 |       4.42556e-09 |      1           | Iris-virginica     |
# |  145 |            6.7 |           3.3 |            5.7 |           2.5 | Iris-virginica  |  3.23769e-228 |       1.64603e-10 |      1           | Iris-virginica     |
# |  146 |            6.7 |           3   |            5.2 |           2.3 | Iris-virginica  |  2.96341e-184 |       5.85508e-07 |      0.999999    | Iris-virginica     |
# |  147 |            6.3 |           2.5 |            5   |           1.9 | Iris-virginica  |  1.13194e-144 |       0.0254458   |      0.974554    | Iris-virginica     |
# |  148 |            6.5 |           3   |            5.2 |           2   | Iris-virginica  |  5.57089e-162 |       0.000370167 |      0.99963     | Iris-virginica     |
# |  149 |            6.2 |           3.4 |            5.4 |           2.3 | Iris-virginica  |  5.05671e-192 |       2.4602e-07  |      1           | Iris-virginica     |
# |  150 |            5.9 |           3   |            5.1 |           1.8 | Iris-virginica  |  2.63202e-141 |       0.056005    |      0.943995    | Iris-virginica     |
# +------+----------------+---------------+----------------+---------------+-----------------+---------------+-------------------+------------------+--------------------+
#
# Akurasi Model Naïve Bayes: 0.9595

# %%
print(f"\nAkurasi Model Naïve Bayes: {accuracy * 100:.2f}%")
# Out:
# Akurasi Model Naïve Bayes: 95.95%

# %% [markdown]
# # 🔍 **Mengapa Data Asli 96% dan Data Bersih 95%?** 🤔
#
# ## 📊 **Perbedaan Akurasi**
# - **Data Asli (dengan 1 outlier) →** 🟢 **96%**
# - **Data Bersih (tanpa outlier) →** 🔵 **95%**
#
# Meskipun hanya **1 baris outlier**, akurasinya sedikit berbeda! Kenapa bisa begitu? 🤷‍♂️
#
# ---
#
# ## 📌 **1. Outlier Bisa Membantu Model Membedakan Kelas?** 🎭
# - Outlier dalam dataset mungkin **secara tidak sengaja membantu model** membedakan kelas lebih baik dalam **dataset training & testing**.
# - Jika outlier membuat model lebih condong ke satu pola tertentu, bisa jadi model lebih cocok dengan data testing, sehingga **akurasi terlihat lebih tinggi (96%)**.
#
# 📝 **Namun, ini bisa berbahaya!**
# - Model mungkin bekerja **baik pada data uji saat ini**, tapi **kurang stabil pada data baru** (real-world).
#
# ---
#
# ## 📌 **2. Pengaruh Outlier terhadap Distribusi Data** 📈
# Naïve Bayes menggunakan **mean (\(\mu\)) dan varians (\(\sigma^2\))** untuk menghitung probabilitas.
#
# Mean dihitung sebagai:
# $$
# \mu = \frac{\sum X}{N}
# $$
#
# Varians dihitung sebagai:
# $$
# \sigma^2 = \frac{\sum (X - \mu)^2}{N}
# $$
#
# Probabilitas likelihood dalam Naïve Bayes dihitung dengan distribusi normal:
# $$
# P(X | \text{Kelas}) = \frac{1}{\sqrt{2\pi\sigma^2}} \exp \left( -\frac{(X - \mu)^2}{2\sigma^2} \right)
# $$
#
# - **Data Asli (dengan outlier)** → Mean & varians berubah sedikit, sehingga probabilitasnya sedikit berbeda.
# - **Data Bersih (tanpa outlier)** → Mean & varians lebih stabil, tapi model kehilangan pola yang mungkin "membantu" klasifikasi.
#
# 💡 **Hasilnya?**
# - Data asli **memiliki distribusi yang sedikit berbeda**, yang **kebetulan cocok dengan data testing**, sehingga akurasinya naik ke **96%**.
#
# ---
#
# ## 📌 **3. Akurasi Naik, Tapi Bisa Overfitting?** 🚀
# - **Data Asli (96%) mungkin sedikit overfitting** terhadap outlier, sehingga tampak lebih akurat dalam dataset ini.
# - **Data Bersih (95%) lebih generalisasi**, jadi meskipun akurasinya sedikit lebih rendah, **model lebih stabil dalam jangka panjang**.
#
# 🛑 **Kesalahan yang sering terjadi:**
# > "Akurasi lebih tinggi berarti model lebih baik!" ❌ **(Tidak selalu benar!)**
#
# ---
#
# ## 🏆 **Kesimpulan**
# ✅ **Perbedaan 1% tidak signifikan**, tetapi menunjukkan bahwa **outlier sedikit mempengaruhi model**.
# ✅ **Akurasi lebih tinggi bukan berarti lebih baik!** Bisa jadi itu hanya karena model menghafal pola dari outlier.
# ✅ **Model tanpa outlier lebih stabil & lebih bisa diandalkan pada data baru!**
#
#
#
# 🎯 **Kesimpulan Akhir:**
# 📢 **Jika outlier tidak masuk akal, lebih baik dihapus agar model lebih generalisasi & tidak hanya menghafal data training!** ✨
